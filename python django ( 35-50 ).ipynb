# %% [markdown]
# # 35. Admin application and How to create Super User in Django .

# %% [markdown]
# # Admin Application :

# %% [raw]
# It is a built-in application provided by Django.
#
# This application provides admin interface for CRUD operations without writing sql statements.
#
# It reads metadata from your models to provide a quick, model-centric interface where trusted users can manage content on your site.
#
# Admin Application can be accessed using http://127.0.0.1:8000/admin
#
#
# note ::
#
#
# Super User is required to login into Admin Application

# %% [markdown]
# # Create Super User  :

# %% [raw]
# note ::  We need super user to login into admin interface of the admin application.
#
# So, [ createsuperuser command ] is used to create super user.
#
#
# Syntax:- python manage.py createsuperuser

# %% [markdown]
# ## below are some imp steps :

# %% [raw]
# So, now in order to use the admin application , we must hit the admin url , but note before hitting the admin url we must run :
#
#
# * makemigrations command  and then  # make migrations command bcoz might be there are chances that we have created our own
#                                     # model class .
#
# * migrate command
#
#
# as some tables are needed to get generated in order to run the admin application properly !! , also note , before using the super user we have to fulfil the demands of the table required for creating the superuser !!!

# %% [raw]
# so , the admin application is present inside our settings.py file :
#
#
# INSTALLED_APPS = [
#
#     'django.contrib.admin',         # admin application
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
#     'app1',
#
# ]
#
#
# so, to use this admin application hit the admin url , by running the command python manage.py runserver .

# %% [raw]
# now in order to use the login page of the admin application , use commands :
#
# * makemigrations command                         # python manage.py makemigrations
#
# * migrate command                                # python manage.py migrate
#
# * then use command  create superuser  !!         # python manage.py createsuperuser
#
#
#
# example :
#
#
#
# PS F:\backend\project25> python manage.py createsuperuser
#
# Username (leave blank to use 'hp'): pankaj
# Email address: pankajkumar12861@gmail.com
# Password:
# Password (again):
# The password is too similar to the email address.
# Bypass password validation and create user anyway? [y/N]: y
#
# Superuser created successfully.
#
# now runserver and use admin url !!
#
# So ,now we can login using the username and password we have created !!

# %% [markdown]
# # 36. How to Register Model Class and use _str_ method in django .

# %% [markdown]
# # How to Register Model :

# %% [raw]
# We are registering our table which we has created using model class, to default admin interface.
#
#
# To Register Follow:-
#
#
# • Open admin.py file which is inside Application Folder
#
# • Import your own Model Class created inside Application’s models.py
#
# • admin.site.register(ModelClassName)
#
#
# Example:-
#
#
# • Open admin.py
#
# • from enroll.models import Student
#
# • admin.site.register(Student)
#
#
#
# now after that we are actually able to see the model's table in the admin application .
#
#
# and now if enter the data inside the table then , then it will show a particular row as ( student object1 ), ( student object2 )
# and so on . Now if we don't want to represent a particular as the ( student object1 ), ( student object2 ) then we ust the
# str() method .

# %% [markdown]
# # __str__( ) Method :

# %% [raw]
# The __str__() method is called whenever you call str() on an object. To display an object in the Django admin site and as the value inserted into a template when it displays an object.Thus, you should always return a nice,( human-readable representation) of the model from the __str__() method.
#
#
# Write this Method in [ your own model class ] which is inside [ models.py file ].
#
#
# Syntax:-
#
#
# def __str__(self):
# return self.fieldName
#
#
#
# Example:-
#
#
# def __str__(self):
# return self.stuname

# %% [markdown]
# # models.py :

# %% [raw]
# from django.db import models
#
# # Create your models here.
#
# class Student(models.Model):
#
#     stuid=models.IntegerField((""))
#     stuname=models.CharField((""), max_length=50)
#     stuemail=models.EmailField((""), max_length=254)
#     stupass=models.CharField((""), max_length=50)

# %% [markdown]
# # admin.py :

# %% [raw]
# now registering our model class in admin.py file !!
#
# note : by registering the model class we are now able to see the table in our admin application with table name as students !!
#
# i.e :: plural by default !!

# %% [raw]
# from django.contrib import admin
# from app1.models import Student
#
# # Register your models here.
#
# admin.site.register(Student)

# %% [markdown]
# # now commands to run :

# %% [raw]
# * python manage.py makemigrations
#
# * python manage.py migrate
#
# * python manage.py createsuperuser
#
# * python manage.py runserver

# %% [raw]
# now , we can login to admin application !! with user id and password we have created !!

# %% [raw]
# now we can enter the data in our table with option of add student on top right corner !!
#
# and also with each entry the table data will be shown to us in the object format :
#
#
# example :
#
#           student object 1   # where object 1 represents the row 1
#
#           student object 2   # where object 2 represents the row 2

# %% [markdown]
# # example :

# %% [markdown]
# ![Screenshot%202021-09-27%20033646.png](attachment:Screenshot%202021-09-27%20033646.png)

# %% [markdown]
# ### now if we want to see our data represented by the 'stuname' of the rows inside the table then :

# %% [markdown]
# # we will use the __str__ ()  method in models.py file

# %% [raw]
# from django.db import models
#
#
# # Create your models here.
#
# class Student(models.Model):
#     stuid=models.IntegerField((""))
#     stuname=models.CharField((""), max_length=50)
#     stuemail=models.EmailField((""), max_length=254)
#     stupass=models.CharField((""), max_length=50)
#
#
#
#
# def __str__(self):
#     return self.stuname      # the stuname will represent the rows now in our admin application's [ student ] table !!

# %% [raw]
# now run server and see the table !!!

# %% [markdown]
# # 37. ModelAdmin Class and How to register ModelAdmin class in Django

# %% [markdown]
# # method 1 :

# %% [raw]
# ModelAdmin  :
#
# The ModelAdmin class is the representation of a model in the admin interface.
#
# imp*** :
#
# To show database's table’s all data in admin interface we have to create an ModelAdmin class in admin.py file of Application folder.
#
#
#
#
#
# Syntax:-
#
#
#
#
# admin.py :
#
#
#
#
#
# Creating Class :
#
#
#
# Class ModelAdminClassName(admin.ModelAdmin):
# list_display=(‘fieldname1’, ‘fieldname2’, …….)
#
#
#
#
#
# Register Above Created Class :
#
#
#
#
# admin.site.register(ModelClassName, ModelAdminClassName)
#
#
#
#
#
#
# Example: -
#
#
# class StudentAdmin(admin.ModelAdmin):
# list_display=(‘id’, ‘stuid’, ‘stuname’)
# admin.site.register(Student, StudentAdmin)

# %% [markdown]
# # list_display :

# %% [raw]
# Set list_display to control which fields are displayed on the change list page of the admin. If you don’t set list_display, the admin site will display a single column that displays the __str__() representation of each object .
#
#
#
# There are four types of values that can be used in list_display:
#
#
#
# • The name of a model field.
#
# • A callable that accepts one argument, the model instance.
#
# • A string representing a ModelAdmin method that accepts one argument, the model instance.
#
# • A string representing a model attribute or method (without any required arguments).

# %% [markdown]
# # method 2 :

# %% [markdown]
# ## Register Model by Decorator :

# %% [raw]
# A decorator can be used to register ModelAdmin Classes.
#
# Syntax:- @admin.register(ModelClassName1, ModelClassName2,… ,site=custom_admin_site )

# %% [markdown]
# ## Register Model Classes :

# %% [raw]
# @admin.register(ModelClassName)
#
# Creating Class :
#
# Class ModelAdminClassName(admin.ModelAdmin):
# list_display=(‘fieldname1’, ‘fieldname2’, …….)

# %% [markdown]
# # imp imp imp *****

# %% [markdown]
# # Example: -   ( use this only)(preffered !!)

# %% [raw]
# @admin.register(Student)                # registering the model class
#
# class StudentAdmin(admin.ModelAdmin):   # this is the modeladmin class , where we decide which columns to display in the         list_display=(‘id’, ‘stuid’, ‘stuname’) # admin.py file.

# %% [markdown]
# # example :

# %% [markdown]
# ## first create model class(inside app)

# %% [raw]
# from django.db import models
#
# # Create your models here.
# class Student(models.Model):
#     stuid=models.IntegerField((""))
#     stuname=models.CharField((""), max_length=50)
#     stuemail=models.EmailField((""), max_length=254)
#     stupass=models.CharField((""), max_length=50)

# %% [raw]
# note : don't forget to register your app inside  the settings.py file .

# %% [markdown]
# ## now register your model class inside the admin.py file

# %% [raw]
# from django.contrib import admin
# from .models import Student
# # Register your models here.
#
#
# @admin.register(Student)                # registering the model class !!
#
#
#
#
# class StudentAdmin(admin.ModelAdmin):                            # model adminclass to show the data  in the admin app with the
#     list_display=('id','stuid','stuname','stuemail','stupass')   # required fields !!

# %% [raw]
# also , do the following steps which are required to login into your admin application :
#
#
# * python manage.py makemigrations  # fulfiling the demands of the tables required for creating the super user !!
#
# * python manage.py migrate
#
# * python manage.py createsuperuser
#
# * python manage.py runserver !!

# %% [markdown]
# # 38. How to create Django Form using Form API in Django .

# %% [markdown]
# # Django Form  :

# %% [raw]
# Django’s form functionality can simplify and automate vast portions of work like data prepared for display in a form, rendered as HTML, edit using a convenient interface, returned to the server, validated and cleaned up etc and can also do it more securely than most programmers would be able to do in code they wrote themselves.
#
#
#
#
# Django handles three distinct parts of the work involved in forms:
#
#
#
# • preparing and restructuring data to make it ready for rendering
#
# • creating HTML forms for the data
#
# • receiving and processing submitted forms and data from the client

# %% [markdown]
# # Bound and Unbound Forms :

# %% [raw]
# If it’s bound to a set of data, it’s capable of validating that data and rendering the form as HTML with the data displayed in the HTML.
#
# If it’s unbound, it cannot do validation (because there’s no data to validate!), but it can still render the blank form as HTML.

# %% [markdown]
# # Create Django Form using Form Class :

# %% [raw]
# To create Django form we have to create a new file inside application folder lets say file name is forms.py. Now we can write below code inside forms.py to create a form:-
#
#
#
# Syntax:-
#
#
#
# from django import forms
# class FormClassName(forms.Form):
# label=forms.FieldType()
# label=forms.FieldType(label=‘display_label’)
#
#
#
#
#
# (imp !! imp !! imp !!):
#
# Example:-
#
#
#
# from django import forms
# class StudentRegistration(forms.Form):
# name=forms.CharField()                      # Here length is not required  (imp !!)  # 'name' field will be shown at the
# email=forms.EmailField()                    # html code {  <label for="id_name"> ((  Name  : )) </label></th>  }
#
#
#
#
#
#
# output of above  code in html format will be :
#
#
#
#
#
# <tr>
# <th> <label for="id_name">Name:</label></th>
# <td> <input type="text" name="name" required
# id="id_name"> </td>
# </tr>
# <tr>
# <th> <label for="id_email">Email:</label></th>
# <td><input type=“email" name="email" required
# id="id_email"></td>
# </tr>

# %% [markdown]
# # Display Form to User :

# %% [raw]
# • Create an object of Form class in views.py then pass object to template files
#
# • Use Form object in template file

# %% [markdown]
# # Creating Form object in views.py :

# %% [raw]
# First of all create form object inside views.py file then pass this object to template file as a dict.
#
#
#
# views.py :
#
#
# from .forms import StudentRegistration      # forms API  !!
# def showformdata(request):
# fm = StudentRegistration()
# return render(request, ‘enroll/userregistration.html’, {‘form’:fm})

# %% [markdown]
# # Get object from views.py in template file :

# %% [raw]
# # templates/enroll / userregistration.html
#
#
# <!DOCTYPE html>
# <html>
# <body>
# {{form}}
# </body>
# </html>
#
#
#
#
# Note - Form object won’t provide form tag and button you have to write them manually in template file.
#
#
#
#
#
#
# output of above html code :
#
#
#
#
# <tr>
# <th> <label for="id_name">Name:</label></th>
# <td> <input type="text" name="name" required
# id="id_name"> </td>
# </tr>
# <tr>
# <th> <label for="id_email">Email:</label></th>
# <td><input type=“email" name="email" required
# id="id_email"></td>
# </tr>

# %% [markdown]
# # Get object from views.py in template file :

# %% [raw]
# {{form}} doesn’t add form tag and button so we have to add them manually.
#
#
# templates/enroll / userregistration.html :
#
#
# <!DOCTYPE html>
# <html>
# <body>
# <form action =“” method=“get”>        # adding form tag !!
# {{form}}
# <input type=“submit” value=“Submit”>  # adding the button !!
# </form>                               # closing the form !!
# </body>
# </html>
#
#
#
#
#
# output of above html code :
#
#
#
#
# <form action =“” method=“get”>
# <tr>
# <th> <label for="id_name">Name:</label></th>
# <td> <input type="text" name="name" required
# id="id_name"> </td>
# </tr>
# <tr>
# <th> <label for="id_email">Email:</label></th>
# <td><input type=“email" name="email" required
# id="id_email"></td>
# </tr>
# <input type=“submit” value=“Submit”>
# </form>

# %% [markdown]
# # imp points to be noted !!

# %% [raw]
# • The output does not include the <table> and </table> tags, nor does it include the <form> and </form> tags or an <input type="submit"> tag. It’s your job to do that.
#
#
# • Each field type has a default HTML representation. CharField is represented by an <input type="text"> and EmailField by an <input type="email">.
#
#
# • The HTML name for each tag is taken directly from its attribute name in the StudentRegistration class.
#
#
#
# (*** imp !! *** )
#
#
# • The text label for each field e.g. ‘Name:’ and ‘Email:' is generated from the field name by converting all underscores to spaces and upper-casing the first letter.
#
#
# • Each text label is surrounded in an HTML <label> tag, which points to the appropriate form field via its id.
#
#
# • Its id, in turn, is generated by prepending 'id_' to the field name. The id attributes and <label> tags are included in the output by default.
#
#
# • The output uses HTML5 syntax, targeting <!DOCTYPE html>

# %% [markdown]
# # Form Rendering Options :

# %% [raw]
# • {{form}} will render them all.          #  i.e :: form object is responsible for creating the tr,th,td data of the table !!
#
# • {{ form.as_table }} will render them as table cells wrapped in <tr> tags
#
# • {{ form.as_p }} will render them wrapped in <p> tags
#
# • {{ form.as_ul }} will render them wrapped in <li> tags
#
# • {{ form.name_of_field }} will render field manually as given
#
#
#
#
# <form action =“” method=“get”>
# {{form}}
# <input type=“submit” value=“Submit”>
# </form>

# %% [markdown]
# ## example : using  {{ form.as_p }} will render them wrapped in 'p' tags of html

# %% [markdown]
# ## example :

# %% [raw]
# <form action =“” method=“get”>
# {{form.as_p}}
# <input type=“submit” value=“Submit”>
# </form>

# %% [markdown]
# # example :

# %% [raw]
# # inside application
#
#
# forms.py  :
#
#
# from django import forms
# class StudentRegistration(forms.Form):
#  name = forms.CharField()
#  email = forms.EmailField()
#
#
#
#
#
#
#
#
#
# # view function inside application
#
#
#
#
#
#
# views.py :
#
#
#
#
#
# from django.shortcuts import render
# from .forms import StudentRegistration
# # Create your views here.
#
# def showformdata(request):
#  fm = StudentRegistration()
#  return render(request, 'enroll/userregistration.html', {'form':fm})
#
#
#
#
#
#
#
#
#
#
#
# # defining the urls inside the app
#
#
#
#
#
#
# urls.py :
#
#
#
#
#
# from django.urls import path
# from . import views
#
# urlpatterns = [
#     path('registration/', views.showformdata),
# ]
#
#
#
#
#
#
#  # defining the urls at the project level i.e inside the inner project !!
#
#
#
#
#
#
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('regi/', include('enroll.urls'))
# ]
#
#
#
#
#
#
#
#
#
# # html code which will be displayed after hitting the urls with different styles of writting the html code !!
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#  <meta charset="UTF-8">
#  <meta name="viewport" content="width=device-width, initial-scale=1.0">
#  <title>User Registration</title>
# </head>
# <body>
#  <form action="" method="get">
#    {{form}}
#    <input type="submit" value="Submit">
#  </form>
#  <hr>
#  <form action="" method="get">
#   {{form.as_table}}
#   <input type="submit" value="Submit">
#  </form>
#  <hr>
#  <form action="" method="get">
#   {{form.as_p}}
#   <input type="submit" value="Submit">
#  </form>
#  <hr>
#  <form action="" method="get">
#   {{form.as_ul}}
#   <input type="submit" value="Submit">
#  </form>
#  <hr>
#  <form action="" method="get">
#   {{form.name}}
#   {{form.email}}
#   <input type="submit" value="Submit">
#  </form>
# </body>
# </html>

# %% [markdown]
# # output of the different html code :

# %% [markdown]
# ![mrk.png](attachment:mrk.png)

# %% [markdown]
# # 39. configure id attribute and label tag and dynamic initial value in django .

# %% [markdown]
# # Configure id attribute :

# %% [raw]
# auto_id – The id attribute values are generated by prepending id_ to the form field names. This behavior is configurable, though, if you want to change the id convention or remove HTML id attributes and <label> tags entirely.
#
#
#
# Use the auto_id argument to the Form constructor to control the id and label behavior. This argument must be True, False or a string. By default, auto_id is set to the string 'id_%s'.
#
#
# note : the %s will represent the field of a table here !!
#
#
#
# Example:-
#
#
# fm = StudentRegistration(auto_id=False)
# fm = StudentRegistration(auto_id=‘geeky’)
#
#
#
# • If auto_id is set to a string containing the format character '%s', then the form output will include <label> tags, and will [generate id attributes based on the format string ].
#
#
# ex : the sum_%s will generate the  sum_%s where  %s will be taking the field name !!
#
#
#
# • If auto_id is set to True, then the form output will include <label> tags and will [ use the field name as its id ] for each form field.
#
#
# • If auto_id is False, then [ the form output will not include <label> tags nor id attributes ] .
#
#
# • If auto_id is set to any other true value – such as a string that doesn’t include %s – then the library will act as if auto_id is True.

# %% [markdown]
# # Configure label tag :

# %% [raw]
# label_suffix - A translatable string (defaults to a colon (:) in English) that will be appended after any label name when a form is rendered.
#
# It’s possible to customize that character, or omit it entirely, using the label_suffix parameter.
#
# The label suffix is added only if the last character of the label isn’t a punctuation character (in English, those are ., !, ? or :)
#
#
# fm = StudentRegistration(label_suffix=‘ ’)

# %% [markdown]
# # Dynamic initial values :

# %% [raw]
# initial - initial is used to declare the initial value of form fields at runtime.To accomplish this, use the initial argument to a Form. This argument, if given, should be a dictionary mapping field names to initial values. Only include the fields for which you’re specifying an initial value; it’s not necessary to include every field in your form.
#
#
# If a Field defines initial and you include initial when instantiating the Form, then the latter initial will have precedence.

# %% [raw]
# 1 method :
#
#
#
#
# from django import forms
#
# class Registration(forms.Form):
#     stu_name=forms.CharField()
#     stu_email=forms.EmailField()
#     stu_contact=forms.CharField()
#
#
#
#
#
# # Create your views here.
# def registration(reqest):
#     rg=Registration()
#     return render(reqest,'app1/app1.html',{'forms':rg})
#
#
#
#
#
#
# <label for="id_stu_name">Stu name:</label>	                           #   for="id_stu_name"
# <input type="text" name="stu_name" required="" id="id_stu_name">       #   id="id_stu_name"
#
#
#
#
#
#
#
#
#
# 2 method : As, id="id_stu_name" now if we want to remove the id from RHS i.e  id="stu_name" then
#
#
#
#
#
#
# from django.shortcuts import render
# from .forms import Registration
#
# # Create your views here.
#
# def registration(reqest):
#     rg=Registration(auto_id=True)                                 #  (auto_id=True)  or  (auto_id='geeky) works same !!
#     return render(reqest,'app1/app1.html',{'forms':rg})
#
#
#
#
#
#
# <label for="stu_name">Stu name:</label>                            #  for="stu_name" the "stu_name" is the field name .
# <input type="text" name="stu_name" required="" id="stu_name">      #  for="stu_name" the variable here also get changed !!
#                                                                    #  id="stu_name" , the ' id ' is the field name .
#
#
#
#
#
#
#
# 3 method :
#
#
#
#
#
#
# from django.shortcuts import render
# from .forms import Registration
# # Create your views here.
# def registration(reqest):
#     rg=Registration(auto_id=False)
#     return render(reqest,'app1/app1.html',{'forms':rg})
#
#
#
#
#
#
#
# Stu name:                                                 # label tag gets removed and only the field name gets displayed !!
# <input type="text" name="stu_name" required="">
#
#
#
#
#
#
# 4 method :   now if we want to remove the [ required="" id="id_stu_name" ] to [ required= "pankaj_stu_name" ] then ;
#
#
#
#
#
#
# from django.shortcuts import render
# from .forms import Registration
# # Create your views here.
# def registration(reqest):
#     rg=Registration(auto_id='pankaj_%s')                         #  (auto_id='pankaj_%s')  # '8%s' will take the field name !!
#     return render(reqest,'app1/app1.html',{'forms':rg})
#
#
#
#
#
#
# <label for="stu_name">Stu name:</label>                                #  Stu name
# <input type="text" name="stu_name" required="" id="pankaj_stu_name">   #  id="pankaj_stu_name"
#
#
#
#
#
#
#
#
# 5 method : using the label_suffix !!
#
#
#
#
#
#
# from django.shortcuts import render
# from .forms import Registration
# # Create your views here.
# def registration(reqest):
#     rg=Registration(auto_id=True, label_suffix='***')
#     return render(reqest,'app1/app1.html',{'forms':rg})
#
#
#
#
# <label for="stu_name">Stu name***</label>
# <input type="text" name="stu_name" required="" id="stu_name">
#
#
#
#
#
# o/p of html field :
#
#
#              _____
# Stu name*** |____|
#
#
#
#
#
# 6 method : using the initial parameter !!
#
#
#
# from django.shortcuts import render
# from .forms import StudentRegistration
# # Create your views here.
#
#
#
# def showformdata(request):
#  fm = StudentRegistration(auto_id=True, label_suffix=' ', initial={ 'name': 'Sonam' })   # initial !!
#  return render(request, 'enroll/userregistration.html', {'form':fm})

# %% [markdown]
# ## o/p of the initial parameter :

# %% [markdown]
# ![Screenshot%20%28601%29.png](attachment:Screenshot%20%28601%29.png)

# %% [markdown]
# # 40. Ordering form field in django   [gs 30]

# %% [markdown]
# ## Ordering Form Field  :

# %% [raw]
# order_fields(field_order) – This method is used to rearrange the fields any time with a list of field names as in field_order. By default Form.field_order=None, which retains the order in which you define the fields in your form class.
#
# If field_order is a list of field names, the fields are ordered as specified by the list and remaining fields are appended according to the default order. Unknown field names in the list are ignored.
#
#
#
# views.py :
#
#
# fm = StudentRegistration()
# fm.order_fields(field_order=[‘email’, ‘name’ ]   # thats it !!

# %% [markdown]
# ## example :

# %% [markdown]
# ## froms.py :

# %% [raw]
# from django import forms
#
# class Registrtaion(forms.Form):
#     name=forms.CharField()
#     roll=forms.IntegerField()
#     address=forms.CharField()

# %% [markdown]
# ## views.py :

# %% [raw]
# from django.shortcuts import render
# from.forms import Registrtaion
#
# # Create your views here.
#
# def registration(request):
#     fm=Registrtaion()
#     fm.order_fields(field_order=None)
#     return render(request,'app1/app1.html',{'form':fm})

# %% [markdown]
# ## html code :

# %% [raw]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     {{form.as_p}}
# </body>
# </html>

# %% [markdown]
# ## urls.py inside the app1 :

# %% [raw]
# from django.urls import path
# from .import views
# urlpatterns = [
#     path('regi/',views.registration ),
# ]

# %% [markdown]
# ## project urls.py :

# %% [raw]
# from django.contrib import admin
# from django.urls import path,include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('registration/',include('app1.urls')),
# ]

# %% [markdown]
# ## o/p :

# %% [raw]
# Name:
#
# Roll:
#
# Address:

# %% [markdown]
# # now if we want to change the order of the o/p then  :

# %% [markdown]
# ## views.py :

# %% [raw]
# from django.shortcuts import render
# from.forms import Registrtaion
#
# # Create your views here.
#
# def registration(request):
#     fm=Registrtaion()
#     fm.order_fields(field_order=['address','name','roll'])
#     return render(request,'app1/app1.html',{'form':fm})

# %% [markdown]
# ## o/p :

# %% [raw]
# Address:
#
# Name:
#
# Roll:

# %% [markdown]
# # 41. Render form fields manually in django .(project 3)

# %% [raw]
# Each field is available as an attribute of the form using {{form.name_of_field}}
#
# {{ field.label }} - The label of the field.
#
# Example:- {{ form.name.label }}
#
#
#
#
#
# {{ field.label_tag }} - The field’s label wrapped in the appropriate HTML <label> tag. This includes the form’s label_suffix.
#
# The default label_suffix is a colon:
#
# Example:- {{ form.name.label_tag }}
#
#
#
#
#
#
# {{ field.id_for_label }} - The ID that will be used for this field.
#
# Example:- {{ form.name.id_for_label }}

# %% [raw]
# {{ field.value }} - The value of the field.
#
# Example:- {{ form.name.value }}
#
#
#
#
# {{ field.html_name }} - The name of the field that will be used in the input element’s name field. This takes the form prefix into account, if it has been set.
#
# Example:- {{ form.name.html_name }}
#
#
#
# {{ field.help_text }} - Any help text that has been associated with the field.
#
# Example:- {{ form.name.help_text }}
#
#
#
#
# {{ field.field }} - The Field instance from the form class that this BoundField wraps. You can use it to access Field
# attributes.
#
# Example:- {{form.name.field.help_text}}

# %% [markdown]
# # html code :

# %% [raw]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
#
# <body>
#
#     <div>
#         <h2>this is 1st div</h2>
#         <label for="id_name">Name:</label>
#         <input type="text " name="name" required id="id_name">
#         <hr>
#     </div>
#
#
#     <h3>now we will render the same above code using the variables</h3>
#
#
#
#     <div>
#         <h2>this is 2nd div</h2>
#         <label for="{{form.name.id_for_label}}">Name:</label>
#         <input type="text " name="name" required id="id_name">
#         <hr>
#     </div>
#
#
#
#     <div>
#         <h2>this is 3rd div</h2>
#         <h3>if we need the input then field without doing the hardcode </h3>
#         <label for="{{form.name.id_for_label}}">Name:</label>
#         {{form.name}}
#     </div>
#
#
#     <div>
#         <hr>
#         <h2>this is 4th div</h2>
#         <h3>doing the same with the email field i.e getting the i/p for the email field </h3>
#         <label for="{{form.name.id_for_label}}">Name:</label>
#         {{form.name}}
#         <h3>the code below will only only show the i/p not the label </h3>
#         {{form.email}}
#     </div>
#
#
#
#
#
# NOTE NOTE NOTE !!!!  ::
#
#
#
#
#
#     <div>
#         <hr>
#         <h2>this is 5th div</h2>
#         <h2> NOTE : USE THIS ONE MOST OF THE TIME !!! ( imp !!! )</h2>
#         <h3> now using the label tag and the i/p tag without doing the hardcode :</h3>
#         {{form.name.label_tag}}                                             # this will give us ( Name : ) in the label tag !!
#         {{form.name}}
#     </div>
#
#
#
#
#
#
#     <div>
#         <hr>
#         <h2>this is 6th div</h2>
#         <h2>this is div 6 : to get the label only then use ---> form.name.label</h2>
#         {{form.name.label}}
#         <h2> to get the default value inside the i/p then use ---> form.name.value</h2>
#         {{form.name.value}}
#     </div>
#
#
#
#     <div>
#         <h2>this is 7th div</h2>
#         <h3>using the help text</h3>
#         <hr>
#         {{form.name.label_tag}}
#         {{form.name}}
#         {{form.name.help_text}}
#     </div>
#
#
#
#
#     <hr>
#
#
#
#     <div>
#         <h2>this is 8th div</h2>
#         <h3> form.name.field.required :this will show us that whether our this field is required or not !!</h3>
#         {{form.name.label_tag}}
#         {{form.name}}
#         {{form.name.field.required}}
#     </div>
#
#
#
#
# </body>
#
# </html>

# %% [markdown]
# ## on inspecting we can see the changes :

# %% [markdown]
# ![mrk-2.png](attachment:mrk-2.png)

# %% [markdown]
# # also :

# %% [markdown]
# ![mrk-2.png](attachment:mrk-2.png)

# %% [markdown]
# # o/p in chrome :

# %% [markdown]
# ![mrk.png](attachment:mrk.png)

# %% [markdown]
# ## putting the initial value inside our forms i/p :

# %% [markdown]
# ### we will use the  forms.py file here :

# %% [raw]
# from django import forms
#
# class Registrtaion(forms.Form):
#     name=forms.CharField(initial='pankaj')
#     email=forms.EmailField()

# %% [raw]
# which will set the initial value to 'pankaj' i.e it will be shown as predefined i/p for our field 'name'  :
#
#
# so html o/p :
#
#
# name : pankaj

# %% [markdown]
# ### using the help text inside the forms.py file :

# %% [raw]
# from django import forms
#
# class Registrtaion(forms.Form):
#     name=forms.CharField(help_text='**this is help text** this field will take only 10 char')  # help text !!
#     email=forms.EmailField()

# %% [markdown]
# ### html code :

# %% [raw]
#  <div>
#         <h3>using the help text</h3>
#         <hr>
#         {{form.name.label_tag}}
#         {{form.name}}
#         {{form.name.help_text}}
#     </div>

# %% [markdown]
# ### o/p :

# %% [raw]
# Name:     **this is help text** this field will take only 10 char  [it will be shown to the user !!]

# %% [markdown]
# ##  now using the :  {{form.name.field.required}}

# %% [raw]
# <div>
#      <h3> form.name.field.required :this will show us that whether our this field is required or not !!</h3>
#      {{form.name.label_tag}}
#      {{form.name}}                  # it will display the html code where the 'required ' fieldis present !!
#      {{form.name.field.required}}   # o/p will show us True as boolean after the i/p field !!
#  </div>

# %% [markdown]
# ## o/p :

# %% [raw]
# Name:                 True

# %% [markdown]
# # 42. loop form fields and form hidden fields in django . (gs 32)

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
#
# class StudentRegistration(forms.Form):
#  name = forms.CharField()
#  email = forms.EmailField()
#  mobile = forms.IntegerField()

# %% [markdown]
# ## views.py :

# %% [raw]
# from django.shortcuts import render
# from .forms import StudentRegistration
#
# # Create your views here.
#
# def showformdata(request):
#  fm = StudentRegistration()
#  return render(request, 'enroll/userregistration.html', {'form':fm})

# %% [markdown]
# ## html file code :

# %% [raw]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#  <meta charset="UTF-8">
#  <meta name="viewport" content="width=device-width, initial-scale=1.0">
#  <title>User Registration</title>
# </head>
# <body>
#  <form action="" method="get">
#
#
#   {%  for field in form %}     # for loop used !!
#     {{field.label_tag}}
#     {{field}}
#   {% endfor %}
#
#
#   <input type="submit" value="Submit">
#  </form>
# </body>
# </html>

# %% [markdown]
# ## o/p :

# %% [markdown]
# ![mrk.png](attachment:mrk.png)

# %% [markdown]
# # now for the hidden fields :

# %% [raw]
# {{ field.is_hidden }} - This attribute is True if the form field is a hidden field and False otherwise. It’s not particularly useful as a template variable, but could be useful in conditional tests such as
#
# {% if field.is_hidden %}
# {# Do something special #}
# {% endif %}

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django.forms import widgets
#
# class StudentRegistration(forms.Form):
#  name = forms.CharField()
#  email = forms.EmailField()
#  mobile = forms.IntegerField()
#  key=forms.CharField(widget=forms.HiddenInput)   # hidden field !!

# %% [markdown]
# ## views.py :

# %% [raw]
# from django.shortcuts import render
# from .forms import StudentRegistration
# # Create your views here.
#
# def showformdata(request):
#  fm = StudentRegistration()
#  return render(request, 'enroll/userregistration.html', {'form':fm})

# %% [markdown]
# ## html file code :

# %% [raw]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#  <meta charset="UTF-8">
#  <meta name="viewport" content="width=device-width, initial-scale=1.0">
#  <title>User Registration</title>
# </head>
#
# <body>
#
#  <form action="" method="get">
#
#
#   {%  for field in form.visible_fields %}
#     {{field.label_tag}}
#     {{field}}
#   {% endfor %}
#
#
#
#
#
#   **** note note note !! ****
#
#
#
#
#
#   {%  for hiddenfield in form.hidden_fields %}
#     {{hiddenfield}} # this will not display the i/p as it is a hidden field but on inspecting the page it will be present there
#   {% endfor %}
#
#
#   <input type="submit" value="Submit">
#
#  </form>
# </body>
#
# </html>

# %% [markdown]
# ## hidden field won't get displayed in the html o/p : (as we haven't included the label tag )

# %% [markdown]
# ![mrk.png](attachment:mrk.png)

# %% [markdown]
# ## note :

# %% [raw]
# hidden field is present on inspecting !!but won't get displayed as we haven't included the label tag !!

# %% [markdown]
# # 43. Form Field Argument in Django .

# %% [markdown]
# ## Form Field :

# %% [raw]
# A form’s fields are themselves classes; they manage form data and perform validation when a form is submitted.
#
#
# Syntax:- FieldType(**kwargs)
#
#
#
# Example:-
#
# IntegerField()
# CharField(required)
# CharField(required, widget=forms.PasswordInput)
#
#
#
# from django import forms
# class StudentRegistration(forms.Form):
# name = forms.CharField()

# %% [markdown]
# ## Field Arguments :

# %% [raw]
# required - It take True or False value. By default, each Field class assumes the required value is True.
#
#
# label - The label argument lets you specify the “human-friendly” label for the field. This is used when the Field is displayed in a Form.
#
#
# label_suffix - The label_suffix argument lets you override the form’s label_suffix on a per-field basis.
#
#
# initial - The initial argument lets you specify the initial value to use when rendering this Field in an unbound Form.
#
#
# disabled - The disabled boolean argument, when set to True, disables a form field using the disabled HTML attribute so that it won’t be editable by users. Even if a user tampers with the field’s value submitted to the server, it will be ignored in favor of the value from the form’s initial data.
#
#
# help_text - The help_text argument lets you specify descriptive text for this Field. If you provide help_text, it will be displayed next to the Field when the Field is rendered.
#
#
# error_messages - The error_messages argument lets you override the default messages that the field will raise. Pass in a dictionary with keys matching the error messages you want to override.
#
#
#
# Example:- name=forms.CharField(error_messages={'required':'Enter Your Name’})
#
#
# validators - The validators argument lets you provide a list of validation functions for the field.
#
#
# localize - The localize argument enables the localization of form data input, as well as the rendered output.
#
#
# widget - The widget argument lets you specify a Widget class to use when rendering the Field.

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
#
# class Registration(forms.Form):
#     name=forms.CharField(label='your name',label_suffix='***',initial='pankaj',required=False,disabled=True,help_text='*limit is     70 char')

# %% [markdown]
# ## views.py :

# %% [raw]
# from django.shortcuts import render
# from .forms import Registration
#
# # Create your views here.
# def registration(request):
#     rg=Registration(initial={'name':'pankaj'})                  # it's priority will be much higher !!
#     return render(request,'app1/app1.html',{'registration':rg})

# %% [markdown]
# # note note note ****

# %% [raw]
# forms.py ::
#
#
#
# from django import forms
#
# class Registration(forms.Form):
#     name=forms.CharField(label='your name',label_suffix='***',initial='pankaj',required=False,disabled=True,help_text='*limit is     70 char')
#
#
#                     # here in forms.py we have defined initial='pankaj'
#
#
#
#
#
#
#
#
#
# views.py ::
#
#
#
#
#
#
# from django.shortcuts import render
# from .forms import Registration
#
# # Create your views here.
# def registration(request):
#     rg=Registration(initial={'name':'pankaj'})                  # it's priority will be much higher !!
#     return render(request,'app1/app1.html',{'registration':rg})
#
#
#
#
#
#
#                     # here in views.py we have defined initial='pankaj'
#
#
# So, the views.py file will have more priority !!!

# %% [markdown]
# ## html o/p :

# %% [markdown]
# ![mrk.png](attachment:mrk.png)

# %% [markdown]
# # 44. Form widgets in Django

# %% [markdown]
# ## Widget :

# %% [raw]
# A widget is Django’s representation of an HTML input element.
#
# The widget handles the rendering of the HTML, and the extraction of data from a GET/POST dictionary that corresponds to the widget.
#
# The HTML generated by the built-in widgets uses HTML5 syntax, targeting <!DOCTYPE html>.
#
# Whenever you specify a field on a form, Django will use a default widget that is appropriate to the type of data that is to be displayed.
#
# Each field type has an appropriate default Widget class, but these can be overridden as required.
#
# Form fields deal with the logic of input validation and are used directly in templates.
#
# Widgets deal with rendering of HTML form input elements on the web page and extraction of raw submitted data.
#
#
#
# Example:-
#
# TextInput
#
# Textarea

# %% [markdown]
# ## Widget :

# %% [raw]
# attrs - A dictionary containing HTML attributes to be set on the rendered widget.
#
# If you assign a value of True or False to an attribute, it will be rendered as an HTML5 boolean attribute.
#
# Example:-
#
# feedback=forms.CharField(widget=forms.TextInput(attrs={'class':'somecss1 somecss2', 'id':'uniqueid'}))

# %% [raw]
# attrs - A dictionary containing HTML attributes to be set on the rendered widget.
#
# If you assign a value of True or False to an attribute, it will be rendered as an HTML5 boolean attribute.
#
# Example:-
#
# feedback=forms.CharField(widget=forms.TextInput(attrs={'class':'somecss1 somecss2', 'id':'uniqueid'}))

# %% [markdown]
# ## Built-in Widgets :

# %% [raw]
# TextInput - It renders as: <input type="text" ...>
#
# Example:- name = forms.CharField(widget=forms.TextInput)
#
# NumberInput - It renders as: <input type="number" ...>
#
# EmailInput - It renders as: <input type="email" ...>
#
# URLInput – It renders as: <input type="url" ...>
#
# PasswordInput - It renders as: <input type="password" ...>
#
# It take one optional argument render_value which determines whether the widget will have a value filled in when the form is re-displayed after a validation error (default is False).

# %% [markdown]
# # without using widget :

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
#
# class Registration(forms.Form):
#     name=forms.CharField()       # default input ='text'

# %% [markdown]
# ## html o/p :

# %% [raw]
# <input type="text" name="name" required="" id="id_name">

# %% [markdown]
# # with using the widgets :

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
# from django.forms import widgets
#
# class Registration(forms.Form):
#     name=forms.CharField(widget=forms.PasswordInput)   # PasswordInput

# %% [markdown]
# ## html o/p :

# %% [raw]
# <input type="password" name="name" required="" id="id_name">  # input type changed to { input type="password" }

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
# from django.forms import widgets
#
# class Registration(forms.Form):
#     name=forms.CharField(widget=forms.HiddenInput)    # HiddenInput

# %% [markdown]
# ## html o/p :

# %% [raw]
# <input type="hidden" name="name" id="id_name">

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
# from django.forms import widgets
#
# class Registration(forms.Form):
#     name=forms.CharField(widget=forms.Textarea)    # Textarea

# %% [markdown]
# ## html o/p :

# %% [raw]
# <textarea name="name" cols="40" rows="10" required="" id="id_name"></textarea>

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
# from django.forms import widgets
#
# class Registration(forms.Form):
#     name=forms.CharField(widget=forms.CheckboxInput)

# %% [markdown]
# ## html o/p :

# %% [raw]
# <input type="checkbox" name="name" required="" id="id_name">

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
# from django.forms import widgets
#
# class Registration(forms.Form):
#     name=forms.CharField(widget=forms.CheckboxInput)

# %% [markdown]
# ## html o/p :

# %% [raw]
# <input type="file" name="name" required="" id="id_name">

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
# from django.forms import widgets
#
# class Registration(forms.Form):
#     name=forms.CharField(widget=forms.TextInput(attrs={'class':'somecss1'}))  # TextInput(attrs={'class':'somecss1'})
#
#
#
# # (widget=forms.TextInput(attrs={'class':'somecss1'})  # we can basically use the 'attrs' i.e atrribute in the TextInput field                                                          # type , by which now we can define the 'class':'somecss1' due to which
#                                                        # now we are able to define css for the field 'name' .

# %% [markdown]
# ## html o/p :

# %% [raw]
# <input type="text" name="name" class="somecss1" required="" id="id_name">
#
#
# # {'class':'somecss1'}  , this class can be used to define the css for the particular field !!

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
# from django.forms import widgets
#
# class Registration(forms.Form):
#     name=forms.CharField(widget=forms.TextInput(attrs={'class':'somecss1','id':'unique id '}))     # 'id':'unique id '

# %% [markdown]
# ## html o/p :

# %% [raw]
# <input type="text" name="name" class="somecss1" id="unique id " required="">           # id="unique id "

# %% [markdown]
# # 45. Difference between GET and POST in django

# %% [raw]
# <!DOCTYPE html>
# <html>
# <body>
# <form method=“get”>                  #  method=“get”
# {{form}}
# <input type=“submit” value=“Submit”>
# </form>
# </body>
# </html>
#
#
#
#
# <!DOCTYPE html>
# <html>
# <body>
# <form method=“post”>                 #  method=“post”
# {{form}}
# <input type=“submit” value=“Submit”>
# </form>
# </body>
# </html>

# %% [markdown]
# # GET and POST

# %% [raw]
# • GET should be used only for requests that do not affect the state of the system.
#
#
# • Any request that could be used to change the state of the system should use POST.
#
#
# • GET would also be unsuitable for a password form, because the password would appear in the URL, and thus, also in browser       history and server logs, all in plain text. Neither would it be suitable for large quantities of data, or for binary data,       such as an image. A Web application that uses GET requests for admin forms is a security risk: it can be easy for an attacker   to mimic a form’s request to gain access to sensitive parts of the system.
#
#
# • POST, coupled with other protections like Django’s CSRF protection offers more control over access.
#
#
# • GET, by contrast, bundles the submitted data into a string, and uses this to compose a URL. The URL contains the address where   the data must be sent, as well as the data keys and values.
#
#
# • Django’s login form is returned using the POST method, in which the browser bundles up the form data, encodes it for             transmission, sends it to the server, and then receives back its response.
#
#
# • GET is suitable for things like a web search form, because the URLs that represent a GET request can easily be bookmarked,       shared, or resubmitted.

# %% [markdown]
# # What is Cross Site Request Forgery (CSRF/ XSRF) :

# %% [raw]
# A Cross-site request forgery hole is when a malicious site can cause a visitor's browser to make a request to your server that causes a change on the server. The server thinks that because the request comes with the user's cookies, the user wanted to submit that form.

# %% [markdown]
# ![mrk.png](attachment:mrk.png)

# %% [markdown]
# # What is Cross Site Request Forgery (CSRF) :

# %% [raw]
# Depending on which forms on your site are vulnerable, an attacker might be able to do the following to your victims:
#
# • Log the victim out of your site.
#
# • Change the victim's site preferences on your site.
#
# • Post a comment on your site using the victim's login.
#
# • Transfer funds to another user's account.
#
#
#
#
# Attacks can also be based on the victim's IP address rather than cookies:
#
#
# • Post an anonymous comment that is shown as coming from the victim's IP address.
#
# • Modify settings on a device such as a wireless router or cable modem.
#
# • Modify an intranet wiki page.
#
# • Perform a distributed password-guessing attack without a botnet.

# %% [markdown]
# # Cross Site Request Forgery (CSRF) Token

# %% [raw]
# Django provides CSRF Protection with csrf_token which we need to add inside form tag. This token will add a hidden input field with random value in form tag.
#
#
# templates/enroll / userregistration.html
# <!DOCTYPE html>
# <html>
# <body>
# <form method=“post”> {% csrf_token %}   # this csrf token will add the hidden i/p field  , whose type is 'hidden' and
# {{form}}                                # name="csrfmiddlewaretoken" with value="ghfu9565+9fwefwf78737^&*^%^%$*7"
# <input type=“submit” value=“Submit”>    # and this { value="ghfu9565+9fwefwf78737^&*^%^%$*7" } keeps on changing due to which
# </form>                                 # it is impossible to hack the system !!!
# </body>
# </html>

# %% [markdown]
# # imp ***

# %% [raw]
# this csrf token will add the hidden i/p field  , whose type is   'hidden'  and   with   name="csrfmiddlewaretoken"     with value="ghfu9565+9fwefwf78737^&*^%^%$*7" . So  this { value="ghfu9565+9fwefwf78737^&*^%^%$*7" } keeps on changing everytime we send the url request or refresh due to which it is impossible to hack the system !!!

# %% [markdown]
# # 46. create form using method POST and CSRF  Token in Django

# %% [markdown]
# ## Get Django Form Data :

# %% [raw]
# • Validate Data/ Field Validation
#
# • Get Cleaned Data

# %% [markdown]
# ## How to send GET Request :

# %% [raw]
# • Open browser and write url hit enter this is by default get request
#
# • Anchor Tag
#
# • Form tag contains method=‘GET’
#
# • Form tag with specifying method is by default GET

# %% [markdown]
# ## How to send POST Request :

# %% [raw]
# • form tag contains method=‘POST’

# %% [markdown]
# # 47. How to get Form data and validate data in django

# %% [markdown]
# ## do the task too :    it is must !!!  for proper understanding
#
# ### see video (47)  from [ 4.00-5.20 min , 13.00 - 14.00 , 18.30 - 19.50 , 12.00 - 13.50  , 23.00 - 24.00 , 27.20 - 27.40  ]

# %% [raw]
# note few points:
#
#     jb bhi submit hoga then post request send hoga !!

# %% [markdown]
# ## Django Form and Field Validation :

# %% [raw]
# is_valid( ) - This method is used to run validation and return a Boolean designating whether the data was valid as True or not as False. This returns True or False.
#
#
# Syntax:- Form.is_valid()
#
#
# each data which is valid is clean data , and we can access the clean data using the cleaned_data .
#
#
#
# cleaned_data – This attribute is used to access clean data. Each field in a Form class is responsible not only for validating data, but also for “cleaning” it normalizing it to a consistent format. This is a nice feature, because it allows data for a particular field to be input in a variety of ways, always resulting in consistent output.
#
#
#
# *** note ***
#
#
# Once you’ve created a Form instance with a set of data and validated it, you can access the clean data via its cleaned_data attribute.
#
#
# Any text based field such as CharField or EmailField always cleans the input into a string.
#
# If your data does not validate, the cleaned_data dictionary contains only the valid fields.
#
# cleaned_data will always only contain a key for fields defined in the Form, even if you pass extra data when you define the Form.
#
# When the Form is valid, cleaned_data will include a key and value for all its fields, even if the data didn’t include a value for some optional fields.

# %% [markdown]
# # Get Django Form Data in Terminal

# %% [raw]
# 1. First of all Create form inside forms.py file
#
#
#
# forms.py :
#
#
#
# from django import forms
# class StudentRegistration(forms.Form):
# name=forms.CharField()
# email=forms.EmailField()
#
#
#
#
#
# 2. Get submitted Data in views.py
#
#
#
#
#
# views.py :
#
#
#
#
#
# from .forms import StudentRegistration
# def showformdata(request):
# if request.method==‘POST’:
#   fm = StudentRegistration(request.POST)  # along with the form data which we have filled the 'fm' object will get created !!
#   if fm.is_valid():                       # now this will valid the data of the form !!
#     print(‘Form Validated’)
#     print(‘Name:’, fm.cleaned_data[‘name’])
#     print(‘email:’, fm.cleaned_data[‘email’])
# else:
#     fm = StudentRegistration()
#
# return render(request, ‘enroll/userregistration.html’, {‘form’:fm})
#
#
#
#
#
#
# NOTE : print(‘Name:’, fm.cleaned_data[‘name’])   # fm.cleaned_data[‘name’]  where 'fm' is the form object , and cleaned data is        the dictionary which holds the form data in the format of the dictionary .
#
#
#
# NOTE : if our data is valid then the data is stored in the cleaned_data in the form of dictionary !!! , and the dictionary key
#        will be the field names , so when we access the data using the key , then the value of that particular key will be              displayed .
#
#
#
#
#
#
#  # first of all on calling the url it is by default GET request .
#
#
#
#  # the data which is valid is called cleaned data !! , the valid data is stored inside the cleaned_data in the format of the
#    dictionary , with the field name as the key of the dictionary !!
#
#
#
#  # when we hit the submit  the form using the submit button ,  the POST request will be sent to the views.py file . So ,
#    the data which we have entered in the form will now get validated using [  fm.is_valid()  ] and we  can access the valid data
#    of the form using the  [  print(‘Name:’, fm.cleaned_data[‘name’]) , [ print(‘email:’, fm.cleaned_data[‘email’])  ] as the        valid data will be present inside the dictionary in cleaned_data , in this    way we can actually access the data inside the    form !!
#
#
#
# # note the value attribute is present in case of the POST method , where as in case of the GET method the value attribute is not
#   present.
#
#
#
#
#
# POST method :
#
#
#
#
#
# this is the post request , when u hit the "submit button" in the form  !!
# FORM IS VALID and so the DATA inside it too !!
# the data is inside the cleaned_data in the format of the dictionary !! given below
#
# <tr><th><label for="id_name">Name:</label></th><td><input type="text" name="name" [  value="pankaj"  ]required id="id_name"></td></tr>
# <tr><th><label for="id_email">Email:</label></th><td><input type="email" name="email" value="pankaj15@gmail.com" required id="id_email"></td></tr>
# {'name': 'pankaj', 'email': 'pankaj15@gmail.com'}
#
#
#
#
#
#
# GET method :
#
#
#
#
#
# this is the get request on hitting the url
# <tr><th><label for="id_name">Name:</label></th><td><input type="text" name="name" required id="id_name"></td></tr>
# <tr><th><label for="id_email">Email:</label></th><td><input type="email" name="email" required id="id_email"></td></tr>
#
#
#
#
#
#
#
# 3. Get object from views.py in template file
#
#
#
#
# templates/enroll / userregistration.html
#
#
#
#
# <!DOCTYPE html>
# <html>
# <body>
# <form method=“POST”> {% csrf_token%}
# {{form.as_p}}
# <input type=“submit” value=“Submit”>
# </form>
# </body>
# </html>

# %% [markdown]
# ## example : project B

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
#
# class Registration(forms.Form):
#     name=forms.CharField()
#     email=forms.EmailField()

# %% [markdown]
# ## project urls.py :

# %% [raw]
# from django.contrib import admin
# from django.urls import path,include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('',include('app1.urls')),
# ]

# %% [markdown]
# ## app urls.py :

# %% [raw]
# from django.urls import path
# from django.urls.conf import include
# from .import views
#
# urlpatterns = [
#     path('',views.regi)
# ]

# %% [markdown]
# ## views.py :

# %% [raw]
# from django.shortcuts import render
# from .forms import Registration
#
#
#
# # Create your views here.
#
#
#
#
# def regi(request):
#
#
#     if request.method=="POST":
#         print(' this is the post request , when u hit the "submit button" in the form  !!')
#         r=Registration(request.POST)
#         if r.is_valid():
#             print(" FORM IS VALID and so the DATA inside it too !!")
#             print('the data is inside the cleaned_data in the format of the dictionary !! given below')
#             print(r)
#             print(r.cleaned_data)
#         return render(request,'app1/app2.html')
#
#
#     else :
#         print('this is the get request on hitting the url')
#         r=Registration()
#         print(r)
#
#
#     return render(request,'app1/app1.html',{'obj':r})

# %% [markdown]
# ## note ***

# %% [raw]
# this will display the data in the same url !! which is a blank url i.e at the home page !!

# %% [markdown]
# ## html file :

# %% [raw]
# app1.html :
#
#
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
#
#
# <body>
#        <form action="" me'>
#          {{obj.as_p}}
#        <input type="submit" value="submit">
# </body>
#
# </html>
#
#
#
#
#
#
#
# app2.html :
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
#
# <body>
#     <form action="" method='post'>
#         {% csrf_token %}
#         {{obj.as_p}}
#         <input type="submit" value="submit">
#     </form>
# </body>
#
# </html>
#
#
#
#
#
#
#
# app3.html :
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             color: red;
#         }
#     </style>
# </head>
# <body>
#     <h3> <i> form data submitted successfully ... !!! </i></h3>
# </body>
# </html>

# %% [markdown]
# ## now ,if we want to display the success message in the other page with different url then :

# %% [markdown]
# # main urls.py :

# %% [raw]
# from django.contrib import admin
# from django.urls import path,include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('',include('app1.urls'))
# ]

# %% [markdown]
# # app urls.py :

# %% [raw]
# from django.urls import path
# from django.urls.conf import include
# from .import views
#
# urlpatterns = [
#     path('',views.regi),
#     path('thankyou/',views.thankyou)
# ]

# %% [markdown]
# # forms.py :

# %% [raw]
# from django import forms
#
# class Registration(forms.Form):
#     name=forms.CharField()
#     email=forms.EmailField()

# %% [markdown]
# # imp ***

# %% [markdown]
# # views.py :  using [ from django.http import HttpResponseRedirect]

# %% [markdown]
# ## to display the information in the new html page i.e app3.html :

# %% [raw]
# from django.shortcuts import render
# from .forms import Registration
#
#
#
#
# from django.http import HttpResponseRedirect    #   imp ****
#
#
#
# # Create your views here.
#
#
# def thankyou(request):
#     return render(request,'app1/app3.html')
#
#
#
# def regi(request):
#     if request.method=="POST":
#         print(' this is the post request , when u hit the "submit button" in the form  !!')
#         r=Registration(request.POST)
#         if r.is_valid():
#             print(" FORM IS VALID and so the DATA inside it too !!")
#             print('the data is inside the cleaned_data in the format of the dictionary !! given below')
#             print(r)
#             print(r.cleaned_data)
#         return HttpResponseRedirect('thankyou/')               # app3.html file will get rendered !!
#
#     else :
#         print('this is the get request on hitting the url')
#         r=Registration()
#         print(r)
#
#     return render(request,'app1/app1.html',{'obj':r})

# %% [markdown]
# # app3.html :

# %% [raw]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body {
#             color: darkred;
#         }
#     </style>
# </head>
#
# <body>
#     <h3> you have succesfully submitted whole data !!</h3>
# </body>
#
# </html>

# %% [markdown]
# ## 49.Form field type Charfield Bolleanfiled integerfield decimalfield slugfield etc in django .

# %% [markdown]
# ## imp ***  also see the video (49) from 15.00min-16.25 min

# %% [raw]
# from django import forms
# class StudentRegistration(forms.Form):
#
# name = forms.CharField(min_length=5, max_length=50, strip=False , empty_value='Sonam',error_messages={'required':'Enter Your Name'})
#
#  roll = forms.IntegerField(min_value=5, max_value=40)
#
#  price = forms.DecimalField(min_value=5, max_value=40, max_digits=4, decimal_places=1)
#
#  rate = forms.FloatField(min_value=5, max_value=40)
#
#  comment=forms.SlugField()
#
#  email=forms.EmailField(min_length=5, max_length=50)
#
#  website=forms.URLField(min_length=5, max_length=50)
#
#  password=forms.CharField(min_length=5, max_length=50, widget=forms.PasswordInput)
#
#  description=forms.CharField(widget=forms.Textarea)
#
#  feedback=forms.CharField(min_length=5, max_length=50, widget=forms.TextInput(attrs={'class':'somecss1 somecss2', 'id':'uniqueid'}))
#
#  notes=forms.CharField(widget=forms.Textarea(attrs={'rows':3, 'cols':50}))
#
#  agree = forms.BooleanField( label_suffix='', label='I Agree')

# %% [markdown]
# # program :  project C

# %% [raw]
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('regi/', include('enroll.urls'))
# ]
#
#
#
#
#
#
# from django.urls import path
# from . import views
#
# urlpatterns = [
#     path('registration/', views.showformdata),
# ]
#
#
#
#
#
#
# from django import forms
# class StudentRegistration(forms.Form):
#
#
#
#  name = forms.CharField(min_length=5, max_length=50, strip=False , empty_value='Sonam',error_messages={'required':'Enter Your     Name'})
#
#  roll = forms.IntegerField(min_value=5, max_value=40)
#
#  price = forms.DecimalField(min_value=5, max_value=40, max_digits=4, decimal_places=1)
#
#  rate = forms.FloatField(min_value=5, max_value=40)
#
#  comment=forms.SlugField()
#
#  email=forms.EmailField(min_length=5, max_length=50)
#
#  website=forms.URLField(min_length=5, max_length=50)
#
#  password=forms.CharField(min_length=5, max_length=50, widget=forms.PasswordInput)
#
#  description=forms.CharField(widget=forms.Textarea)
#
#  feedback=forms.CharField(min_length=5, max_length=50, widget=forms.TextInput(attrs={'class':'somecss1 somecss2', 'id':'uniqueid'}))
#
#  notes=forms.CharField(widget=forms.Textarea(attrs={'rows':3, 'cols':50}))
#
#  agree = forms.BooleanField( label_suffix='', label='I Agree')
#
#
#
#
#
# NOTE NOTE NOTE :
#
#
#
#
# # note : all these validations are getting run bcoz we have used is_valid() in views.py file.
#
#
# name = forms.CharField(min_length=5, max_length=50, strip=False , empty_value='Sonam',error_messages={'required':'Enter Your     Name'})
#
#
# so , note all these validation i.e :
#
#
#
# (min_length=5, max_length=50, strip=False , empty_value='Sonam',error_messages={'required':'Enter Your Name'}) are executing bcoz , we know that the field have the validations which we have given inside it , but to run these validation we have to use the [ is_valid ] method.
#
#
#
# from django.shortcuts import render
# from django.http import HttpResponseRedirect
# from .forms import StudentRegistration
#
# # Create your views here.
#
# def showformdata(request):
#  if request.method == 'POST':
#   fm = StudentRegistration(request.POST)
#   if fm.is_valid():
#    print('Form Validated')
#    print('Name:', fm.cleaned_data['name'])
#    print('Roll:', fm.cleaned_data['roll'])
#    print('Price:', fm.cleaned_data['price'])
#    print('Rate:', fm.cleaned_data['rate'])
#    print('Comment:', fm.cleaned_data['comment'])
#    print('Email:', fm.cleaned_data['email'])
#    print('Website:', fm.cleaned_data['website'])
#    print('Password:', fm.cleaned_data['password'])
#    print('Description:', fm.cleaned_data['description'])
#    print('Feedback:', fm.cleaned_data['feedback'])
#    print('Notes:', fm.cleaned_data['notes'])
#    print('Agree:', fm.cleaned_data['agree'])
#
#  else:
#   fm = StudentRegistration()
#
#  return render(request, 'enroll/userregistration.html', {'form':fm})
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#  <meta charset="UTF-8">
#  <meta name="viewport" content="width=device-width, initial-scale=1.0">
#  <title>User Registration</title>
# </head>
# <body>
#  <form action="" method="POST" novalidate>
#  {% csrf_token %}
#   {{form.as_p}}
#   <input type="submit" value="Submit">
#  </form>
# </body>
# </html>

# %% [markdown]
# # 50. cleaning and validating specific form field in django

# %% [markdown]
# ## Cleaning and Validating Specific Field

# %% [raw]
# clean_<fieldname>() - This method is called on a form subclass where <fieldname> is replaced with the name of the form field attribute.
#
# This method does any cleaning that is specific to that particular attribute, unrelated to the type of field that it is.
#
# This method is not passed any parameters.
#
# You will need to look up the value of the field in self.cleaned_data and remember that it will be a Python object at this point, not the original string submitted in the form.

# %% [markdown]
# ## Cleaning and Validating Specific Field :

# %% [raw]
# forms.py  :
#
#
# from django import forms
# class StudentRegistration(forms.Form):
# name=forms.CharField()
# email=forms.EmailField()
# password=forms.CharField(widget=forms.PasswordInput)
#
# def clean_name(self):         # using the function inside the form class for raising the error for a particular field  !!!
# valname = self.cleaned_data[‘name’]       //       valname = self.cleaned_data.get(‘name’)
# if len(valname) < 4:
# raise forms.ValidationError(‘Enter more than or equal 4’)
# return valname

# %% [markdown]
# # example of raising the validation error :

# %% [raw]
# from django import forms
#
# class Registration(forms.Form):
#     name=forms.CharField()
#     roll=forms.IntegerField()
#     contact=forms.IntegerField()
#     address=forms.CharField()
#     email=forms.EmailField()
#     def clean_name(self):                       # note : this is how we raise the validation error while filling the form.
#         valname = self.cleaned_data.get("name")
#         if len(valname) < 4:
#             raise forms.ValidationError('please enter the valid name with more than 4 char  ')
#         return valname +'correct'              # this is submitting of the valname + string 'correct' !!
#
#     def clean_roll(self):
#         valname = self.cleaned_data.get("roll")
#         if len(str(valname)) > 2:
#             raise forms.ValidationError('please enter the valid roll of 2 digits or 1 digit ')
#         return str(valname) +'correct'

# %% [markdown]
# # note :

# %% [raw]
# priority will be given to forms.py file to check the validations , after that the other validation will be  given chance which is present in the views.py file i.e [ is_valid() ]
#
# . As if the data for the particular field is validated using the [ def clean_name(self) ] in forms.py file , then as we have       used the POST method the data will further go to the views.py file for checking all the validations of the form field.

# %% [markdown]
# # note :

# %% [raw]
# return valname +'correct'              # this is submitting of the valname + string 'correct' !!

# %% [raw]
# So , basically :
#
#
# return valname +'correct'              # this is submitting of the valname + string 'correct' !!
#
#
#
# this combined data of the valname which is holding the 'name' key value  and string 'correct' will be submitted on hitting the submit button the web page which  will further call the post request , and this post request will be further goes to the views.py file where the request.method=="POST" will further print the form's key values .
#
#
#
#
# example : [ 'name'+correct ] suppose if we have put 'name':pankaj then o/p at the terminal of the views.py file will show us the
#
# name :pankajcorrect !!

# %% [markdown]
# # example :

# %% [markdown]
# ## forms.py :

# %% [raw]
# from django import forms
#
# class Registration(forms.Form):
#     name=forms.CharField()
#     roll=forms.IntegerField()
#     contact=forms.IntegerField()
#     address=forms.CharField()
#     email=forms.EmailField()
#     def clean_name(self):
#         valname = self.cleaned_data.get("name")
#         if len(valname) < 4:
#             raise forms.ValidationError('please enter the valid name with more than 4 char  ')
#         return valname +'correct'
#
#     def clean_roll(self):
#         valname = self.cleaned_data.get("roll")
#         if len(str(valname)) > 2:
#             raise forms.ValidationError('please enter the valid roll of 2 digits or 1 digit ')
#         return str(valname) +'correct'

# %% [markdown]
# # app1.html :

# %% [raw]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>User Registration</title>
#     <style>
#         body {
#             background-color: darkcyan;
#         }
#     </style>
# </head>
#
# <body>
#     <hr>
#     <h2> <i> fill the following details : </i></h2>
#     <hr>
#     <form action="" method="POST" novalidate>
#         <table>
#             {% csrf_token %}
#             {{x}}
#         </table>
#         <input type="submit" value="Submit">
#     </form>
#     <hr>
# </body>
#
# </html>

# %% [markdown]
# # app2.html :

# %% [raw]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             color: white;
#             background-color: black;
#         }
#     </style>
# </head>
# <body>
#     <h2> you have successfully submitted whole data !!</h2>
# </body>
# </html>

# %% [markdown]
# # views.py :

# %% [raw]
# from django.shortcuts import render
#
# from app1.forms import Registration
# from .forms import Registration
# from django.http import HttpResponseRedirect
# # Create your views here.
#
# def thankyou(request):
#     return render(request,'app1/app2.html')
#
# def regifunc(request):
#     if request.method=="POST":
#         r=Registration(request.POST)
#         if r.is_valid():
#             print()
#             print()
#             print('congratulations , your data is valid !! CHECK THE DETAILS BELOW :')
#             print(r.cleaned_data)
#             print('Name:', r.cleaned_data['name'])
#             print('Roll:', r.cleaned_data['roll'])
#             print()
#             print()
#             return HttpResponseRedirect('thankyou/')
#
#     else :
#         r=Registration()
#
#     return render(request,'app1/app1.html',{'x':r})

# %% [markdown]
# # note ::

# %% [raw]
# that the data to printed on the terminal will be shown us as we have written the print code in the views.py file which will get printed the moment we press the submit button and the post method will execute the details of the forms.py file , which is inside the cleaned_data .

# %% [markdown]
# ### so , if we fill the correct details inside the form then it will show us the data at the terminal like :

# %% [raw]
# congratulations , your data is valid !! CHECK THE DETAILS BELOW :
# {'name': 'pankajcorrect', 'roll': '2correct', 'contact': 3453, 'address': '572787', 'email': 'pankajkumar16821@gmail.com'}
# Name: pankajcorrect
# Roll: 2correct
