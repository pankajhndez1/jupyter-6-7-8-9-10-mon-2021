# %% [markdown]
# # Framework :

# %% [raw]
# A Framework is a set of conceptual structure and guidelines, used to build something useful.
#
# A framework may include predefined classes and functions that can be used to process input, manage hardware devices, and interact with system software.
#
# The purpose of the framework is to allow developers to focus on building a unique feature for their Projects rather than writing code from scratch

# %% [markdown]
# # Why use Framework :

# %% [raw]
# • Collection of tools
#
# • No need to start from scratch
#
# • Save Time
#
# • Improve Productivity
#
# • Clean Code
#
# • Reusable Code
#
# • Testing
#
# • Debugging

# %% [markdown]
# # Web Framework :

# %% [raw]
# A Web Framework (WF) or Web Application Framework (WAF) which helps to build Web Applications.
#
# Web frameworks provide tools and libraries to simplify common web development operations. This can include web services, APIs, and other resources.
#
# Web frameworks help with a variety of tasks, from templating and database access to session management and code reuse.
#
# More than 80% of all web app frameworks rely on the Model View Controller architecture
#
#
# * Some Web Framework :
#
# • Laravel
#
# • Codeigniter
#
# • Zend
#
# • Django
#
# • Spring

# %% [markdown]
# # Model View Template (MVT)

# %% [raw]
# The MVT is an design pattern that separates an application into three main logical components Model, View, and Template.
# Each of these component has their own role in a Project.

# %% [markdown]
# # model :

# %% [raw]
# The Model responsible to handle database. It is a data access layer which handles the data.

# %% [markdown]
# # View :

# %% [raw]
# The user can send request by interacting with template, the view handles these requests and sends to Model then get appropriate response from the Model, sends response to template.
#
# It may also have required logics. It works as a mediator between Template and Model.

# %% [markdown]
# # Template :

# %% [raw]
# It represents how data should be presented to the application user. User can read or write the data from template. Basically it is responsible for showing end user content, we can say it is user interface.
#
# It may consists of HTML, CSS, JS mixed with Django Template Language.

# %% [markdown]
# ![Screenshot%202021-09-01%20004415.png](attachment:Screenshot%202021-09-01%20004415.png)

# %% [markdown]
# # can also be represented as :

# %% [markdown]
# ![Screenshot%202021-09-01%20004226.png](attachment:Screenshot%202021-09-01%20004226.png)

# %% [markdown]
# # Why use MVT

# %% [raw]
# • Organized Code
#
# • Independent Block
#
# • Reduces the complexity of web applications
#
# • Easy to Maintain
#
# • Easy to modify

# %% [markdown]
# # Django

# %% [raw]
# Django is a free, open-source Python based High-Level Web Framework. It follows the Model View Template (MVT) architectural pattern.
#
# It was originally created by Adrian Holovaty and Simon Willison.
#
# It was created on 2003 at Lawrence Journal World Newspaper.
#
# It was released publicly under a BSD license in July 2005.
#
# In June 2008, it was announced that Django Software Foundation (DSF) would maintain Django in the future.

# %% [markdown]
# # What we can build with Django :

# %% [raw]
# We can build High End Web Applications.
#
# It encourages rapid development and clean, pragmatic design.
#
# • Youtube
#
# • Instagram
#
# • Bitbucket
#
# • NASA
#
# • Spotify

# %% [markdown]
# # Advantages of Django:

# %% [raw]
# • Open Source
#
# • Fast
#
# • Secure
#
# • Scalable
#
# • Authentication
#
# • Versatile
#
# • Provides Development Web Server by Default.
#
# • Provides SQLite Database by

# %% [markdown]
# # Django Project :

# %% [raw]
# A Django Project may contain multiple Project Application, which means a group of Application and files is called as Django Project. An Application is a Part of Django Project.
#
#
# SchoolProject
#
# • Registration App
#
# • Fees App
#
# • Exam App
#
# • Attendance App
#
# • Result App

# %% [markdown]
# ![Screenshot%202021-09-01%20004226.png](attachment:Screenshot%202021-09-01%20004226.png)

# %% [markdown]
# # note : most imp !!

# %% [markdown]
# ![Screenshot%202021-09-01%20004226.png](attachment:Screenshot%202021-09-01%20004226.png)

# %% [markdown]
# # note **

# %% [raw]
# * outer project folder / root directory is known as outer project folder/ root directory because it contains the ( manage.py )   file .

# %% [markdown]
# # Django Project Directory Structure :

# %% [raw]
# * __init__.py – The folder which contains __init__.py file is considered as python package.

# %% [raw]
# * wsgi.py – WSGI (Web Server Gateway Interface) is a specification that describes how a web server communicates with web           applications, and how web applications can be chained together to process one request. WSGI provided a ( standard for           synchronous Python apps ) .

# %% [raw]
# * asgi.py – ASGI (Asynchronous Server Gateway Interface) is a spiritual successor to WSGI, intended to provide a standard         interface between async-capable Python web servers, frameworks, and applications. ASGI provides ( standard for both             asynchronous and synchronous apps) .

# %% [markdown]
# # most imp file  !!

# %% [markdown]
# # settings.py

# %% [raw]
# * settings.py – This file contains all the information or data about project settings.
#
#   E.g.:- Database Config information, Template, Installed Application, Validators etc.
#
#
#   example : if we want to work with the database then we have to define the database name in settings.py  along with the           information of mysql i.e port number ,database name , host , password etc .
#
#
#
# (most imp !!)
#
#
# *  Also, A Django Project may contain multiple Project Application, which means a group of Apps and files is called as Django      Project. So we have to add these apps in our project !! , which is done inside the settings.py file !!
#
# *  also , if we make any template too , then we have to code for the template inside the settings.py file  !!
#
# *  also the middleware and validators are also mentioned inside the settings.py file !!

# %% [raw]
# * urls.py – This file contains information of url attached with application.

# %% [raw]
# * manage.py – manage.py is automatically created in each Django project. It is Django’s command-line utility ,also sets the       DJANGO_SETTINGS_MODULE environment variable so that it points to your project’s settings.py file. Generally, when working on     a single Django project, it’s easier to use manage.py than django-admin.

# %% [markdown]
# # so after creating the project , if we run server then !!

# %% [raw]
# to run the server we have to go inside the root directory !! ,
#
# using  :   cd  outer project folder/root directory  i.e geekyshows (outer one ) .

# %% [raw]
# running the server will give us additional folder with some files !! i.e inside the inner project folder the ( _pycache_)
# folder will get created with some cache files of the files which are already present inside the inner project folder and one database file i.e ( db.sqlite3 ) which is initially an empty file :
#
#
# note : even if we delete the ( _pycache_ folder ) which contains the cache files by mistake , then we don't need to worry about        it as we can get these cache files again after running the server again !

# %% [markdown]
# ![Screenshot%202021-09-01%20004226.png](attachment:Screenshot%202021-09-01%20004226.png)

# %% [markdown]
# # so use this command to start a project :

# %% [markdown]
# # command  :

# %% [raw]
#  C:\Users\hp\Desktop>django-admin startproject Projectname

# %% [markdown]
# # example :

# %% [raw]
# C:\Users\hp\Desktop>django-admin startproject geekyshows

# %% [markdown]
# # also note** :

# %% [raw]
# to run the server we have to go inside the root directory !!

# %% [markdown]
# # and for running the server we use this command :

# %% [raw]
# command : python manage.py runserver
#
# note    : [ python manage.py runserver ] , here we write ( python ) first as the ( manage.py ) is a python file .

# %% [markdown]
# # discussion of the files we get after creating the project :

# %% [markdown]
# # (__init__.py ) file :

# %% [raw]
# The folder which contains __init__.py file is considered as python package. It is normally an empty file .

# %% [markdown]
# # ( wsgi.py ) file :

# %% [markdown]
# ![Screenshot%202021-09-01%20004226.png](attachment:Screenshot%202021-09-01%20004226.png)

# %% [raw]
# note : here , [  os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'geekyshows.settings’)  ]
#
#
# * 'DJANGO_SETTINGS_MODULE' is the ( eniviroment varibale ) , and here in 'geekyshows.settings’  basically we are  Defining        settings  module for environment variable .

# %% [markdown]
# # note :

# %% [raw]
# * application = get_wsgi_application()
#
#   here the ( application ) is an object which is assigned with the function  [   get_wsgi_application()  ]  !!
#   and This function returns WSGI callable which is then assigned to the object ( application ) , which makes ( application ) a
#   callable object !!

# %% [markdown]
# # ( wsgi.py ) brief :

# %% [raw]
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'geekyshows.settings’)

# %% [markdown]
# # how the above line works :

# %% [raw]
# When the WSGI server ( loads ) your ( application ) , Django needs to import the ( settings module ) , that’s where your entire application is defined.
#
# Django uses the DJANGO_SETTINGS_MODULE environment variable to locate the appropriate settings module.
#
#
# * It must contain the dotted path to the settings module. i.e [ 'ProjectName.settings’ ],  ex:-[ 'geekyshows.settings’ ]
#
#
# You can use a different value for development and production; it all depends on how you organize your settings.
#
# If this variable isn’t set, the default wsgi.py sets it to ( mysite.settings ), where mysite is the name of your project.
#
#
# note : That’s how runserver discovers the default settings file by default.
#
#
# Also, WSGI servers are designed to handle many requests concurrently. Frameworks are not made to process thousands of requests and determine how to best route them from the server. WSGI speeds up Python web application development because you only need to know basic things about WSGI.
#
#
# WSGI application is a callable object (a function, method, class, or an instance with a __call__ method that accepts two positional arguments: WSGI environment variables and a callable with two required positional arguments which starts the response; the server side invokes the callable object which returns response

# %% [markdown]
# # similarly ,  ( asgi.py ) file works :

# %% [raw]
# import os
#
# from django.core.asgi import get_asgi_application
#
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'geekyshows.settings’)
#
# application = get_asgi_application()

# %% [markdown]
# # 12. How to create and install application in django

# %% [markdown]
# # Create Django Project :

# %% [raw]
# Syntax: -
#
# django-admin startproject projectname

# %% [markdown]
# # How to Start/Create Application :

# %% [raw]
# A Django project contains one or more applications which means we create application inside Project Folder.
#
# Syntax:- python manage.py startapp appname

# %% [raw]
# Creating One Application inside Project:-
#
# • Go to Project Folder
#
# • Run Command python manage.py startapp Appname
#
# ex : python manage.py startapp course   ( # here course is the app name )

# %% [raw]
# Creating Multiple Applications inside Project:-
#
# • Go to Project Folder
#
# • python manage.py startapp course
#
# • python manage.py startapp fees
#
# • python manage.py startapp result

# %% [markdown]
# # How to Install Application in Our Project :

# %% [raw]
# As we know a Django project can contain multiple application so just creating application inside a project is not enough we also have to install application in our project.
#
# We install application in our project using settings.py file.
#
# settings.py file is available at Project Level which means we can install all the application of project.
#
# This is compulsory otherwise Application won’t be recognized by Django.

# %% [raw]
# so , Open settings.py file and add the app you have created :

# %% [raw]
# INSTALLED_APPS =
#
# [
# ‘django.contrib.admin’,
# ‘application_name1’,
# ‘application_name2’,
# ]
#
# now , Save settings.py File
#
#
#
#
#
# example 1 :
#
#
#
# INSTALLED_APPS = [
# ‘django.contrib.admin’,
# ‘course’,
# ]
#
#
#
# example 2 :
#
#
#
# INSTALLED_APPS = [
# ‘django.contrib.admin’,
# ‘course’,
# ‘fees’,
# ‘result’,

# %% [markdown]
# # Geeky Steps :

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
# • Change Directory to Django Project: cd geekyshows
#
# • Create Django Application: python manage.py startapp course
#
# * so when we create the app course we get the folder ( migration ) along with __init__ file  inside it !!, and along with         course app we get the init ,admin,apps,models,tests and views.py files !!
#
# • Add/Install Application to Django Project (course to geekyshows)
#
#  Open settings.py
#  Add course
# INSTALLED_APPS = [‘django.contrib.admin’,‘course’, ]
#  Save settings.py

# %% [markdown]
# ![Screenshot%202021-09-01%20004226.png](attachment:Screenshot%202021-09-01%20004226.png)

# %% [markdown]
# # Geeky Steps for adding multiple apps :

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
# • Change Directory to Django Project: cd geekyshows
#
# • Create Django Application1: python manage.py startapp course
#
# • Create Django Application2: python manage.py startapp fees
#
# • Create Django Application3: python manage.py startapp result
#
#
#
# note :
#
#
# after creating the different apps we get the same folder and files inside our apps !!
#
# i.e :  on creation of course app, fees app and result app we get the migration folder along with the __init__.py file inside it        Also we get admin.py , apps.py , models.py , test.py and views.py files inside our apps we have created !!
#
#
#
#
# • Add/Install Applications to Django Project
#
#
#  Open settings.py
#
#
#  Add course, fees, result
#
#
# INSTALLED_APPS = [‘django.contrib.admin’,‘course’,‘fees’ , ‘result’ ,]
#
#
#  Save settings.py
#
#
# also note : it is not mandatory to make all the app at the begining of our project !! i.e, we can create app anytime according               to our need !!

# %% [markdown]
# # example :

# %% [markdown]
# ![Screenshot%202021-09-01%20004226.png](attachment:Screenshot%202021-09-01%20004226.png)

# %% [markdown]
# # note :

# %% [raw]
# all the apps must be created in the project folder for which u must change the directory to projectfolder name !!

# %% [raw]
# Also , to install all the apps you have created , you must go to ( settings.py ) file inside the innerproject folder .

# %% [raw]
# so ,now if we want to check that our project is working properly without any mistakes then we must run the server to check so !
# using the command :
#
#
#
# syntax :- python manage.py runserver
#
#
# which will show us [ System check identified no issues (0 silenced) ] , if no errors are found !!
#
# and now to stop the server use ( ctrl+c ) .

# %% [markdown]
# # 13. application directory structure

# %% [raw]
# migrations –  This folder contains __init__.py file which means it’s a python package. It also contains all files which
# are created after running makemigration command . So after running the makemigration command It basically generates the database related files which are basically stored inside the migrations folder !

# %% [markdown]
# # Application Directory Structure

# %% [raw]
# • Go to Project Folder
#
# • Run Command python manage.py startapp course
#
#
# course
#
#     migrations     #  folder we get after creating the app .
#
#     __init__.py    #  migration folder contains the __init__.py file .
#
# __init__.py
#
# admin.py
#
# apps.py
#
# models.py
#
# tests.py
#
# views.py

# %% [markdown]
# # Application Directory Structure :

# %% [raw]
# * migrations – This folder contains __init__.py file which means it’s a python package. It also contains all files which
#   are created after running makemigration command .
#
#
#
#
# * __init__.py – The folder which contains __init__.py file is considered as Python Package.
#
#
#
#
# * admin.py – This file is used to register sql tables so we could perform CRUD operation from Admin Application. Admin           Application is provided by Django to perform CRUD operation.
#
#
#
#
# * apps.py – This file is used to config app.
#
#
#
#
# * models.py – This file is used to create our own model class later these classes will be converted into database table
#   by Django for our application.
#
#
#
#
# * tests.py – This is files is used to create tests.
#
#
#
#
# * views.py – This file is used to create view. We write all the business logic related code in this file

# %% [markdown]
# # note :

# %% [raw]
# * admin.py and models.py files are used more when we have to work with the database !!

# %% [markdown]
# # 15. create function based views

# %% [raw]
# M – Model
#
# V – View
#
# T – Template

# %% [raw]
# View :
#
# • Function Based View
#
# • Class Based View

# %% [markdown]
# # Function Based View :

# %% [raw]
# A function based view, is a Python function that takes a Web request and returns a Web response. This response can be the HTML contents of a Web page, or a redirect, or a 404 error, or an XML document, or an image or anything.
#
#
# Each view function takes an HttpRequest object as its first parameter. The view returns an HttpResponse object that contains the generated response. Each view function is responsible for returning an HttpResponse object. We will call these functions as view function or view function of application or view.

# %% [markdown]
# ![Screenshot%202021-09-10%20153828.png](attachment:Screenshot%202021-09-10%20153828.png)

# %% [raw]
# Function Based Views :
#
#
# We use views.py file of the application to write functions which may contain business logic of application, later it required to define url name for this function in the urls.py file of the project.
#
#
# example 1 :
#
#
#
#
#
# views.py :
#
#
#
# from django.http import HttpResponse
#
# def function_name1 (request):                  # HttpRequest Object
# return HttpResponse(‘html/variable/text’)      # HttpResponse Object
#
#
#
#
#
#
#
# example 2 :
#
#
#
#
# views.py :
#
#
# from django.http import HttpResponse
#
# def function_name2 (request):
# return HttpResponse(‘html/variable/text’)

# %% [markdown]
# # note ***

# %% [raw]
# Where HttpResponse is class which is in ( django.http module ) so we have to import it before using HttpResponse .

# %% [markdown]
# # defining the urls :

# %% [raw]
# Single Application with Single view function  :
#
#
#
# views.py :
#
#
#
# from django.http import HttpResponse
#
#
#
# def learn_django(request):
# return HttpResponse(‘Hello Django’)
#
#
#
#
#
# urls.py  :
#
#
#
# urlpatterns =[
# path(‘admin/’, admin.site.urls),
# path(‘learndj/’, views.learn_django),
# ]

# %% [markdown]
# # examples :

# %% [raw]
# Function Based Views :
#
#
# Single Application with multiple view functions.
#
#
#
#
# views.py :
#
#
# from django.http import HttpResponse
#
# def learn_django(request):
# return HttpResponse(‘Hello Django’)
#
#
#
# def learn_python(request):
# return HttpResponse(‘<h1>Hello Python</h1>’)
#
#
# NOTE ****  :: the response will be inside ('') i.e single quotes !!!!!!
#
#
#
#
#
# urls.py :
#
#
# urlpatterns = [
# path(‘learndj/’, views.learn_django),
# path(‘learnpy/’, views.learn_python),
# ]

# %% [markdown]
# # Steps to follow  :

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
#
# • Change Directory to Django Project: cd geekyshows
#
#
# • Create Django Application: python manage.py startapp course
#
#
# • Add/Install Application to Django Project (course to geekyshows) using settings.py file .
#
#
# INSTALLED_APPS = [‘django.contrib.admin’,‘course’, ]
#
#
# • Write View Function inside views.py file
#
#
# • Open views.py
#
#
# • Import HttpResponse class from [ django.http module ,  i.e : from django.http import HttpResponse ]
#
#
# • Write view Function
#
#
# def learn_django(request):
# return HttpResponse(‘Hello Django’)
#
#
# • Save views.py

# %% [markdown]
# # 16. URL dispatcher or URL Pattern inside project in Django

# %% [raw]
# URL Dispatcher :
#
#
# To design URLs for app, you create a Python module informally named urls.py This module is pure Python code and is a mapping between URL path expressions to view functions.This mapping can be as short or as long as needed. It can reference other mappings. It’s pure Python code so it can be constructed dynamically.
#
#
#
#
# urls.py :
#
#
#
# urlpatterns = [
# path(route, view, kwargs=None, name=None),
# ]
#
#
#
# urls.py :
#
#
#
# urlpatterns = [
# path(‘learndj/’, views.learn_django),
# ]

# %% [markdown]
# # path ( ) :

# %% [raw]
# path(route, view, kwargs=None, name=None) - It returns an element for inclusion in urlpatterns.

# %% [raw]
# Where,
#
#
# • The route argument should be a string or gettext_lazy() that contains a URL pattern. The string may contain angle brackets e.g. <username> to capture part of the URL and send it as a keyword argument to the view.
#
#
# • The view argument is a view function or the result of as_view() for class-based views. It can also be django.urls.include().
#
#
# • The kwargs argument allows you to pass additional arguments to the view function or method. It should be a dictionary.
#
#
# • name is used to perform URL reversing

# %% [markdown]
# # path ( ) :

# %% [raw]
# urls.py :
#
#
# urlpatterns = [
# path(route, view, kwargs=None, name=None),
# ]
#
#
#
# urls.py :
#
#
# urlpatterns = [
# path(‘learndj/’, views.learn_Django, {‘check’: ‘OK’ }, name=‘learn_django’),
# ]

# %% [markdown]
# # URL Pattern inside Project :

# %% [raw]
# urls.py file is used to define url pattern attached with  view of application or view function of application.
#
# urls.py file is located inside ( inner project folder ) not inside application folder which means we define url at project level for applications. Defined url name will be used by application user to get response from the application or view function of application.
#
#
# Steps:-
#
#
#
# • Open urls.py
#
# • Import Module (Views file) of the application
#
# • Write URL Name and Map it with function
#
#
#
# urlpatterns = [
# path(route, view, kwargs=None, name=None)
# ]
#
#
#
#
#
# *from course import views
#
#
# urlpatterns = [
# path(‘learndj/’, views.learn_django),
# ]
#
#
# learndj is mapped with learn_django function which is inside views.py file.

# %% [markdown]
# # URL Pattern inside Project : see it !!

# %% [raw]
# Single Application with Single function.
#
#
#
#
# views.py :
#
#
#
# from django.http import HttpResponse
#
# def learn_django(request):
# return HttpResponse(‘Hello Django’)
#
#
#
#
# urls.py :
#
#
#
#
# from course import views
# urlpatterns = [
# path(‘learndj/’, views.learn_django),
# ]

# %% [raw]
# We can define multiple url for one view function. Which means we can access same view function with multiple urls.
#
#
#
#
# example :
#
#
#
# urls.py :
#
#
#
# from course import views
#
#
# urlpatterns = [
# path(‘learndj/’, views.learn_django),
# path(‘altlearndj/’, views.learn_django),
# ]

# %% [raw]
# Single Application with multiple functions :
#
#
#
#
# views.py :
#
#
#
#
# from django.http import HttpResponse
#
# def learn_django(request):
# return HttpResponse(‘Hello Django’)
#
#
# def learn_python(request):
# return HttpResponse(‘<h1>Hello Python</h1>’)
#
#
#
#
#
#
# urls.py :
#
#
#
#
# from course import views
#
# urlpatterns = [
# path(‘learndj/’, views.learn_django),
# path(‘learnpy/’, views.learn_python),
# ]

# %% [markdown]
# # Steps to remember : note*** must see it !!!

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
# • Change Directory to Django Project: cd geekyshows
#
# • Create Django Application: python manage.py startapp course
#
# • Add/Install Application to Django Project (course to geekyshows) usingsettings.py file INSTALLED_APPS
#
# • Write View Function inside views.py file
#
# • Define url for view function of application
#
#
#
#  Open urls.py
#
#
#
#  Import views Module of the application
#
# from course import views
#
#
#
#  Write url Pattern
#
# urlpatterns = [ path(‘learndj/’, views.learn_django),
# path(‘learnpy/’, views.learn_python), ]
#
#
#
#  Save urls.py

# %% [markdown]
# # 17. Multiple application  inside project and their function based views in Django

# %% [raw]
# Syntax:- python manage.py startapp appname
#
#
#
# Creating One Application inside Project Steps:-
#
# • Go to Project Folder (cd geekyshows)
#
# • Run Command python manage.py startapp course
#
# Creating Multiple Applications inside Project Steps:-
#
# • Go to Project Folder (cd geekyshows)
#
# • python manage.py startapp course
#
# • python manage.py startapp fees

# %% [markdown]
# # How to Install Application in Our Project :

# %% [raw]
# As we know a project can contain multiple application so just creating application inside a project is not enough we also have to install application in our project.We install application in our project using setting.py file. Setting.py file is available at Project Level which means we can install all the application of project.
#
# This is compulsory otherwise Application won’t be recognized by Django.
#
#
#
# Open setting.py file :
#
#
# INSTALLED_APPS = [
# ‘django.contrib.admin’,
# ‘application_name1’,
# ‘application_name2’,
# ]
#
#
# Save settings.py File

# %% [markdown]
# # Function Based Views :

# %% [raw]
# example 1 :
#
#
# views.py of course :
#
#
# from django.http import HttpResponse
#
# def learn_django(request):
# return HttpResponse(‘Hello Django’)
#
#
#
# example 2 :
#
#
# views.py of fees :
#
#
# from django.http import HttpResponse
#
# def fees_django(request):
# return HttpResponse(‘300’)

# %% [markdown]
# # URL Pattern :

# %% [raw]
# views.py of course :
#
#
# from django.http import HttpResponse
#
# def learn_django(request):
# return HttpResponse(‘Hello Django’)
#
#
#
#
#
#
#
# views.py of fees :
#
#
# from django.http import HttpResponse
#
# def fees_django(request):
# return HttpResponse(‘300’)
#
#
#
#
#
# now definig the url patterns !! -->
#
#
#
#
#
# urls.py :
#
#
#
# from course import views as cv
# from fees import views as fv
#
#
# urlpatterns = [
# path(‘learndj/’, cv.learn_django),    # note : here the urls's called function is not inside the inverted commas !!
# path(‘feesdj/’, fv.fees_django),      # i.e  [ cv.learn_django ] and  [ fv.fees_django ] is not inside the  inverted commas !!
# ]
#
#
#
#
# or define it like  the below given way :
#
#
#
#
# urls.py :
#
#
#
# from course.views import learn_django
# from fees.views import fees_django
#
#
# urlpatterns = [
# path(‘learndj/’, learn_django),
# path(‘feesdj/’, fees_django),
# ]

# %% [markdown]
# # note imp point ***

# %% [raw]
# path(‘learndj/’, cv.learn_django),    # note : here the urls's called function is not inside the inverted commas !!
# path(‘feesdj/’, fv.fees_django),      # i.e  [ cv.learn_django ] and  [ fv.fees_django ] is not inside the  inverted commas !!

# %% [markdown]
# # Steps to remember :

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
# • Change Directory to Django Project: cd geekyshows
#
# • Create Django Application1: python manage.py startapp course
#
# • Create Django Application2: python manage.py startapp fees
#
# • Add/Install Applications to Django Project (course and fees to geekyshows)
#
# using settings.py INSTALLED_APPS
#
# • Write View Function inside views.py file
#
# • Define url for view function of application using urls.py file

# %% [markdown]
# # 18. URL dispatcher or URL pattern inside application in Django .

# %% [markdown]
# # note ***

# %% [raw]
# ( URLconf module )  means  ( urls.py file )

# %% [markdown]
# # Why URL Pattern inside Application :

# %% [raw]
# So far we have learnt to define url pattern at project level for our all application. This approach increases the dependency of applications in project which means if we want to use a particular application for our another project we may face issues.
# Our each application should be independent or less depend on project so we could use our applications in different projects easily without worrying about urls.py available in Project Folder.
#
#
#
# Following are the benefits of defining url pattern inside Application :
#
# • Reduces the dependency of Application
#
# • Enhance Application performance.
#
# • Reusability of application becomes easy.

# %% [markdown]
# # include ( ) :

# %% [raw]
# A function that takes a full Python import path to another URLconf module that should be “included” in this place.
# Optionally, the application namespace and instance namespace where the entries will be included into can also be specified.
#
# include() also accepts as an argument either an iterable that returns URL patterns or a 2-tuple containing such iterable
# plus the names of the application namespaces.
#
# * urlpatterns can “include” other URLconf modules.
#
#
#
#
# Syntax:-
#
#
# 1) include(module, namespace=None)
#
# 2) include(pattern_list)
#
# 3) include((pattern_list, app_namespace), namespace=None)
#
#
# Where,
#
# module – URLconf module (or module name)
#
# namespace (str) – Instance namespace for the URL entries being included
#
# pattern_list – Iterable of path() and/or re_path() instances.
#
# app_namespace (str) – Application namespace for the URL entries being included

# %% [markdown]
# # Example:-

# %% [raw]
# from django.urls import include, path
#
# urlpatterns = [
# path(‘cor/', include(‘course.urls')),      #   [ ‘course.urls’ ]    must be inside the single quotes !!
# ]
#
#
# so ,
#
#
#
# syntax :-
#
# path(route, view, kwargs=None, name=None)
#
#
# The view argument is a view function or the result of as_view() for class-based views. It can also be an django.urls.include().

# %% [markdown]
# # note :****

# %% [raw]
# the url's function are get searched after running the server , firstly inside the main urls.py file of project level will be searched !!!!!, then inside the application level urls.py file !! which then further calls the views function of the application attached with the urls.py file of the application !!

# %% [raw]
# urls.py in Project Folder :
#
# from django.urls import path, include
#
# urlpatterns = [
# path(‘cor/’, include(‘course.urls’)),
# ]

# %% [markdown]
# # note imp point *******

# %% [raw]
# * path(‘cor/’, include(‘course.urls’))    the     [ ‘course.urls’ ]    must be inside the single quotes !!
#
#
# * otherwise it will show us the error !!

# %% [markdown]
# # most most imp steps for urls inside the applications **** :

# %% [markdown]
# # a) Write URL Pattern inside Application

# %% [raw]
# • Create an urls.py file inside each application (in case multiple application).
#
# • Write all url pattern related to application, in urls.py file available inside application.
#
# • Include Application’s urls.py file inside Project’s urls.py file.

# %% [markdown]
# # b ) views.py in Application Folder :

# %% [raw]
# example :
#
#
#
# a). HttpResponse object inside inverted commas .
#
#
# from django.http import HttpResponse
#
# def learn_django(request):            # the name (request) could be anyname which specifies that it is a Httprequest object !!
# return HttpResponse(‘Hello Django’)   # Httpresponse inside the inverted commas !
#
#
#
#
#
#
# b).  HttpResponse object inside inverted commas .
#
#
# def learn_python(request):
# return HttpResponse(‘<h1>Hello Python</h1>’)         #  inside the inverted commas !
#
#
#
#
#
#
# c). Rendering the HTML file inside inverted commas .
#
#
# def app1_func1(request):
#     x={'name':'pankaj'}
#     return render(request,'app1/app1.html',x)        # inside the inverted commas !

# %% [markdown]
# # c) urls.py in Application Folder :

# %% [raw]
# from course import views
#
# urlpatterns = [
# path(‘learndj/’, views.learn_django),
# path(‘learnpy/’, views.learn_python),
# ]

# %% [markdown]
# # d) urls.py in Project Folder

# %% [raw]
# from django.urls import path, include
#
# urlpatterns = [
# path(‘cor/’, include(‘course.urls’)),   # [ ‘course.urls’ ]    must be inside the single quotes !!
# ]

# %% [markdown]
# # steps to remember :

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
# • Change Directory to Django Project: cd geekyshows
#
# • Create Django Application: python manage.py startapp course
#
# • Add/Install Application to Django Project using settings.py file INSTALLED_APPS
#
# • Write View Function inside views.py file
#
# • Create an urls.py file inside each application (in case multiple application).
#
# • Write all url pattern related to application, in urls.py file available inside application.
#
# • Include Application’s urls.py file inside Project’s urls.py file

# %% [markdown]
# # NOTE NOTE NOTE **** !!!

# %% [raw]
#  1) defining the url inside the main project file :
#
#
#
# path(‘learndj/’, cv.learn_django),    # note : here the urls's called function is not inside the inverted commas !!
# path(‘feesdj/’, fv.fees_django),      # i.e  [ cv.learn_django ] and  [ fv.fees_django ] is not inside the  inverted commas !!
#
#
#
#
#
#
#
#
#
#
# 2) defining the url for the urls.py file inside the application then use this format :
#
#
#
#
# from django.urls import include, path
#
# urlpatterns = [
# path(‘cor/', include(‘course.urls')),      # [ ‘course.urls’ ]    must be inside the single quotes !! and give comma (,) after
# ]                                          # giving the url !!  i.e  :   [    ),  ]
#
#
#
#
#
#
#
#
#
#
#
# 3) defining the Httpresponse inside the views :
#
#
#
#
# from django.http import HttpResponse
#
# def learn_django(request):
# return HttpResponse(‘Hello Django’)     # everything must be inside the inverted commas !!!

# %% [markdown]
# # 19. Template and how to render Template files in django !!

# %% [raw]
# Template :
#
# A template is a text file. It can generate any text-based format (HTML, XML, CSV, etc.).
#
# A template contains variables, which get replaced with values when the template is evaluated, and tags, which control the logic of the template.
#
# Template is used by view function to represent the data to user. User sends request to view then view contact template afterthat view get information from the template and then view gives response to the users.

# %% [markdown]
# # Create Template Folder and Files :

# %% [raw]
# We create templates folder inside Project Folder. templates folder will contain all html files.
#
#
#
# geekyshows  # outer project folder !!
#
#
# course     # appplication 1
#
# fees       # appplication 2
#
#
# template:          # Template folder
#
# courseone.html     # Template files
# coursetwo.html     # Template files
# feesone.html
# feestwo.html
#
# geekyshows # inner project folder !!
#
# __init__.py
# settings.py
# urls.py
# wsgi.py
# manage.py

# %% [markdown]
# # Add Templates in settings.py :

# %% [raw]
# ## settings.py :
#
#
#
# 1)  INSTALLED_APPS = [
#     ‘course’,
#     ‘fees’,
#      ]
#
#
#
#
# 2) TEMPLATES_DIR = BASE_DIR / ‘templates’
#
#
#
# then add TEMPLATES_DIR in ‘DIRS’ :
#
#
#
# TEMPLATES = [
# {
# ‘DIRS’: [TEMPLATES_DIR],   # note : here the ' DIRS ' basically searches where it have to find the templates files !!!!
# }                          # so here we have given a path where it have to find the template files i.e [TEMPLATES_DIR] !!
# ]                          # and it will also search inside the sub directory of ' templates '

# %% [markdown]
# # steps to remember :

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
# • Create Django Application1: python manage.py startapp course
#
# • Create Django Application2: python manage.py startapp fees
#
# • Add/Install Applications to Django Project (course and fees to geekyshows) using settings.py INSTALLED_APPS
#
# • Create templates folder inside Root Project Directory
#
#
#
#
# • Add templates directory in settings.py
#
# TEMPLATES_DIR = os.path.join(BASE_DIR, ‘templates’)
#
# TEMPLATES_DIR = BASE_DIR / ‘templates’               # use this one !!!  # imp***
#
# TEMPLATES = [ {
# ‘DIRS’: [TEMPLATES_DIR], }
# ]
#
#
#
#
#
#
# # note : here the ' DIRS ' basically searches where it have to find the templates files !!!!                                    # so here we have given a path where it have to find the template files i.e [TEMPLATES_DIR] !!
# # and it will also search inside the sub directory of ' templates ' folder .
#
#
#
# • Create template files inside templates folder
#
# • Write View Function inside views.py file
#
# • Define url for view function of application using urls.py file

# %% [markdown]
# # note **

# %% [raw]
# When we create Template file for application we separate business logic and presentation from the application views.py file.
#
# Now we will write business logic in views.py file and presentation code in template file.

# %% [markdown]
# # Rendering Templates Files :

# %% [raw]
# By Creating Template file for application we separate business logic and presentation for the application views.py file. Now we will write business logic in views.py file and presentation code in html file.
#
# Still views.py will be responsible to process the template files for this we will use render() function in views.py file.
#
#
#
#
# views.py :
#
#
#
# from django.shortcuts import render
#
# def function_name(request):
# Dynamic Data, if else, any python code logic
# return render(request, template_name, context=dict_name, content_type=MIME_type, status=None, using=None)
#
#
#
#
# example :
#
#
# def learn_django(request):
# return render(request, ‘courseone.html’)

# %% [markdown]
# # render ( ) :

# %% [raw]
# render ( ) Function - It combines a given template with a given context dictionary and returns an HttpResponse object with that rendered text.
#
#
#
# Syntax:-
#
#
# render(request, template_name, context=dict_name, content_type=MIME_type, status=None, using=None)
#
#
# Where,
#
#
# request – The request object used to generate this response.*
#
#
# template_name – The full name of a template to use or sequence of template names. If a sequence is given, the first template that exists will be used. *
#
#
# context – A dictionary of values to add to the template context. By default, this is an empty dictionary. If a value in the dictionary is callable, the view will call it just before rendering the template.
#
#
# content_type – The MIME type to use for the resulting document. Defaults to 'text/html'.
#
#
# status – The status code for the response. Defaults to 200.
#
#
# using – The NAME of a template engine to use for loading the template.

# %% [markdown]
# # render ( ) :

# %% [raw]
# Syntax:-
#
#
# render(request, template_name, context=dict_name, content_type=MIME_type, status=None, using=None)
#
#
# Example:-
#
#
# render(request, ‘courseone.html’, context=cname, content_type=‘application/xhtml+xml’)
#
#
#
#
# example :
#
#
# views.py :
#
# from django.shortcuts import render
#
# def learn_django(request):
# return render(request, ‘courseone.html’)

# %% [markdown]
# # steps to remember :

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
# • Create Django Application1: python manage.py startapp course
#
# • Create Django Application2: python manage.py startapp fees
#
# • Add/Install Applications to Django Project (course and fees to geekyshows) using settings.py INSTALLED_APPS
#
# • Create templates folder inside Root Project Directory
#
# • Add templates directory in settings.py
#
# TEMPLATES_DIR = os.path.join(BASE_DIR, ‘templates’)
#
# TEMPLATES_DIR = BASE_DIR / ‘templates’
#
# TEMPLATES = [ {
# ‘DIRS’: [TEMPLATES_DIR], }
# ]
#
#
#
#
# # note : here the ' DIRS ' basically searches where it have to find the templates files !!!!                                    # so here we have given a path where it have to find the template files i.e [TEMPLATES_DIR] !!
# # and it will also search inside the sub directory of ' templates ' folder .
#
#
#
#
# • Create template files inside templates folder
#
# • Write View Function inside views.py file
#
# • Define url for view function of application using urls.py file
#
# • Write Template files code

# %% [markdown]
# # 20.  creating and rendering templates file for each application seprately

# %% [markdown]
# # Create Template Folder and Files :

# %% [raw]
# We can create separate folder inside templates folder for applications then each application will contain only those
# html file which are related to them. This will enhance readability and separate html files according to applications.
#
#
#
# geekyshows       # project folder
#
#
#
#   templates
#
#
#
#    course : html files related to course app
#
#
#           : courseone.html
#             coursetwo.html
#
#
#
#
#    fees   : html files related to fees app
#
#
#           : feesone.html
#             feestwo.html
#
#
#
#
#   geekyshows    # inner project folder
#
#     __init__.py
#     settings.py
#     urls.py
#     wsgi.py
#
#
#   course        # application 1
#
#
#   fees          # application 2
#
#
# manage.py

# %% [markdown]
# # now , Add Templates in settings.py :

# %% [raw]
# settings.py :
#
#
# TEMPLATES_DIR = BASE_DIR / ‘templates’
#
# TEMPLATES = [
# {
# ‘DIRS’: [TEMPLATES_DIR],
# }
# ]
#
#
#
#
# # note : here the ' DIRS ' basically searches where it have to find the templates files !!!!                                    # so here we have given a path where it have to find the template files i.e [TEMPLATES_DIR] !!
# # and it will also search inside the sub directory of ' templates ' folder .

# %% [markdown]
# # steps to remember :

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
# • Create Django Application1: python manage.py startapp course
#
# • Create Django Application2: python manage.py startapp fees
#
# • Add/Install Applications to Django Project (course and fees to geekyshows) using settings.py INSTALLED_APPS
#
# • Create templates folder inside Root Project Directory
#
# • Add templates directory in settings.py
#
# TEMPLATES_DIR = os.path.join(BASE_DIR, ‘templates’)
# TEMPLATES_DIR = BASE_DIR / ‘templates’
#
# TEMPLATES = [ {
# ‘DIRS’: [TEMPLATES_DIR], } ]
#
#
# # note : here the ' DIRS ' basically searches where it have to find the templates files !!!!                                    # so here we have given a path where it have to find the template files i.e [TEMPLATES_DIR] !!
# # and it will also search inside the sub directory of ' templates ' folder .
#
#
#
# • Create Separate Directory for each application, inside templates directory
#
# • Create template files inside templates/temp_application folder/directory
#
# • Write View Function inside views.py file
#
# • Define url for view function of application using urls.py file

# %% [markdown]
# # Write Templates Files :

# %% [raw]
# When we create Template file for application we separate business logic and presentation from the application views.py file.
#
# Now we will write business logic in views.py file and presentation code in template file.

# %% [markdown]
# # Rendering Templates Files :

# %% [raw]
# By Creating Template file for application we separate business logic and presentation from the application views.py file. Now we will write business logic in views.py file and presentation code in html file.
#
#
# Still views.py will be responsible to process the template files for this we will use render() function in views.py file.
#
#
#
#
#
# views.py :
#
#
#
# from django.shortcuts import render
#
# def function_name(request):
# Dynamic Data, if else, any python code logic
# return render(request, template_name, context=dict_name,
# content_type=MIME_type, status=None, using=None)
#
#
#
#
#
#
# views.py :
#
#
#
#
# def learn_django(request):
# return render(request, ‘course/courseone.html’)

# %% [markdown]
# # render ( ) :

# %% [raw]
# Syntax:-
#
#     render(request, template_name, context=dict_name, content_type=MIME_type, status=None, using=None)
#
#
# Example:-
#
# render(request, ‘courseone.html’, context=cname, content_type=‘application/xhtml+xml’)
# render(request, ‘course/courseone.html’, context=cname, content_type=‘application/xhtml+xml’)
# render(request, ‘course/coursetwo.html’)

# %% [markdown]
# # note ****

# %% [raw]
# views.py :
#
#
# from django.shortcuts import render
#
#
# def learn_django(request):
# return render(request, ‘course/courseone.html’)     # ‘course/courseone.html’ [writting the folder name is neccessary !!]

# %% [markdown]
# # steps to remember :

# %% [raw]
# • Create Django Project: django-admin startproject geekyshows
#
# • Create Django Application1: python manage.py startapp course
#
# • Create Django Application2: python manage.py startapp fees
#
# • Add/Install Applications to Django Project (course and fees to geekyshows) using settings.py INSTALLED_APPS
#
# • Create templates folder inside Root Project Directory
#
# • Add templates directory in settings.py
#
# TEMPLATES_DIR = os.path.join(BASE_DIR, ‘templates’)
# TEMPLATES_DIR = BASE_DIR / ‘templates’
#
# TEMPLATES = [ {
# ‘DIRS’: [TEMPLATES_DIR], } ]
#
#
# # note : here the ' DIRS ' basically searches where it have to find the templates files !!!!                                    # so here we have given a path where it have to find the template files i.e [TEMPLATES_DIR] !!
# # and it will also search inside the sub directory of ' templates ' folder .
#
#
#
# • Create Separate Directory for each application, inside templates directory
#
# • Create template files inside templates/temp_application folder/directory
#
# • Write View Function inside views.py file
#
# • Define url for view function of application using urls.py file
#
# • Write Template files code

# %% [markdown]
# # note **** : imp thing !!!!

# %% [raw]
# when we are working with the ( views.py ) file of a particular application then we can work with the ( urls.py ) file of the same application by importing the views file in the urls file using command :
#
#
# example :
#
# from . import views
