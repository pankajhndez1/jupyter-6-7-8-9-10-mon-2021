# %% [markdown]
# # MySQL :

# %% [raw]
# * It is an open source database management system application which will help us to manage the database like store and retrieve   data.
#
# * To work with MySQL ( database management system ) in Python program we have to import ( connector sub module )  of  ( mysql     module ).
#
#
#
# i.e :   [   import mysql.connector   ]

# %% [markdown]
# # Creating Connection

# %% [raw]
# connect() – This method is used to open or establish a new connection with Mysql ( database management system ).
#
# note ***  ::  It returns a connection object representing the connection.

# %% [markdown]
# # Syntax: -

# %% [raw]
# connection_object = connect(user=‘username’, password=‘pass’ host=‘localhost’, port=3306);
#
#
#
# note : ( connection_object ) name could be anything !! , also this connection_object can be used further in our python program !!

# %% [markdown]
# # example : -

# %% [raw]
# 1).
#
#
#
# import mysql.connector
# conn = mysql.connector.connect(user=‘root’, password=‘ ’, host=‘localhost’, port=3306)
#
#
#
# this can also be written as :
#
#
#
# 2).
#
#
#
# import mysql.connector
#
# conn = mysql.connector.connect(
#      user=‘root’,
#      password=‘geek’,
#      host=‘localhost’,
#      port=3306
# )

# %% [raw]
# also note to access the [  connect()  ] we have to write [  mysql.connector.connect()  ]
#
# these information  : (user=‘root’, password=‘geek’, host=‘localhost’, port=3306) are for Mysql .
#
# also , after running the above cell program , if no error is shown to us , means we have successfuly created the connection !!

# %% [markdown]
# # note :

# %% [raw]
# if by mistake we have inserted the wrong password in (user=‘root’, password=‘geek’, host=‘localhost’, port=3306), then we can handle that error using the exception handling !!

# %% [raw]
# import Mysql.connector
#
# try:
#     conn=Mysql.connector.connect(
#          user='root',
#          password='gek',  # password is wrong here !!
#          host='locaalhost',
#          port=3306
# )
#
# except:
#       print('unable to connect')

# %% [markdown]
# # another way to create the connection : ( using dictionary format  )[optional]

# %% [raw]
# import Myssql.connector
#
# config={
#     user:'root'
#     password:'geek'
#     host:'localhost'
#     port:3306
# }
#
# try:
#     conn=Mysql.connector.connect(**config)
#
# except:
#     print(" unable to connect !!")

# %% [raw]
# after running the above program if it doesn't show  " unable to connect !! "  , then it means we have created the connection with  Mysql database management system  !!

# %% [markdown]
# # Check Connection

# %% [raw]
# is_connected() – This method is used to check if the connection to MySQL is established or not. It returns True if the connection is established successfully.

# %% [markdown]
# # Syntax:-

# %% [raw]
# connection_object.is_connected()

# %% [raw]
# note *** :: the connection object is  [ conn  ]

# %% [raw]
# example :-
#
#
# import mysql.connector
# conn = mysql.connector.connect(user=‘root’, password=‘geek’, host=‘localhost’)
#
#
# print( conn.is_connected() )   # returns true !!

# %% [markdown]
# # example :   [optional]

# %% [raw]
# # Creating Connection
#
#
# import mysql.connector
#
# config = {
# 	'user': 'root',
# 	'password': '',
# 	'host': 'localhost',
# 	'port': 3306
# }
#
#
# try:
# 	conn= mysql.connector.connect(**config)
# 	if (conn.is_connected()):                 #    " conn  "   is the connection_obejct   !!
# 		print('Connected')
#
#
# except:
# 	print('Unable to Connect')

# %% [raw]
# so , after creating the connection we can do alot of work with Mysql and then closes the connection !! , which is considered to be a good practice !!

# %% [markdown]
# # Close Connection

# %% [raw]
# close() – This method is used to disconnect the connection.

# %% [markdown]
# # Syntax:- connection_object.close()

# %% [raw]
# eg:-
#
#
# import mysql.connector
# conn = mysql.connector.connect(user=‘root’, password=‘geek’, host=‘localhost’)
#
#
# # Do your work
#
#
# conn.close()    # closing the connection !!  where ( conn ) is the connection object !!

# %% [markdown]
# # note ***

# %% [raw]
# note after closing the connection we can't further do more work with the connection object ( conn ) !!

# %% [markdown]
# # example :

# %% [raw]
# # Close Connection
#
#
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='',
# 		host='localhost',
# 		port=3306
# 	)
# 	if (conn.is_connected()):  # as conn has the scope inside the try indentation only !!
# 		print('Connected')
#
#
#
# except:
# 	print('Unable to Connect')
#
#
#
# conn.close()   # closing the connection with Mysql !!

# %% [markdown]
# # we can check whether our connection is closed or not by using ::  *print(conn.is_connected)

# %% [raw]
# # Close Connection
#
#
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='',
# 		host='localhost',
# 		port=3306                 # depends which port we are using !!
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
#
#
# except:
# 	print('Unable to Connect')
#
#
# print(' BEFORE CLOSE ' ,conn.is_connected)       # will return  : True
#
# conn.close()                                     # closing the connection with Mysql !!
#
# print(' AFTER CLOSE ' ,conn.is_connected)        # will return  : False

# %% [markdown]
# # cursor() Method

# %% [raw]
# This method is used to create cursor class object. We need cursor object so we can call execute() method.

# %% [markdown]
# # Syntax:-

# %% [raw]
# cursor_object = connection_object.cursor()

# %% [markdown]
# # example :

# %% [raw]
# eg:- myc = conn.cursor()  <----- Mysql cursor !!

# %% [markdown]
# # note ***here " myc " is the cursor object !!

# %% [raw]
# so, here the connection_object along with the cursor() method only gives us the  " myc "   which  is the ( cursor object only ) which points the data  , so cursor objects takes the help of [ EXECUTE method ] , which in combination helps us to execute the SQL queries !!
#
# or we can say, cursor object is an object that is used to make the connection for executing SQL queries.
#
# Cursors are used by database programmers to process individual rows returned by database system queries.

# %% [markdown]
# # execute() Method

# %% [raw]
# This method is used to execute given SQL queries. We need cursor object so we can call execute() method.

# %% [markdown]
# # Syntax:-

# %% [raw]
# cursor_object.execute(sql, param=None, multi=False)
#
#
# where :
#
#
# * Sql – It is sql query.
#
#
# * Param – The parameters found in the tuple or dictionary params are bound to the variables in the operation or bound to the     SQL queries !!
#
#
# * Multi – execute() returns an iterator if multi is True.

# %% [markdown]
# # example :

# %% [raw]
# sql =‘SELECT * FROM student’
#
# myc = conn.cursor()
# myc.execute(sql)     # executing the queries using cursor object !!

# %% [markdown]
# # Close Cursor

# %% [raw]
# close () method : closes the cursor, resets all results, and ensures that the cursor object has no reference to its original connection object.

# %% [markdown]
# # Syntax:-

# %% [raw]
# cursor_object.close()

# %% [raw]
# eg:- myc.close()                 # closes the cursor object !!

# %% [markdown]
# # Create Database

# %% [raw]
# import mysql.connector
#
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		port=3306
# 	)
#     if (conn.is_connected()):
# 		print('Connected')
#
#
# except:
# 	print('Unable to Connect')
#
#
#
# sql = ' CREATE DATABASE pdb '
#
# myc = conn.cursor()          # opening the cursor obejct
#
# myc.execute(sql)
#
# myc.close()                  # closing the cursor obejct
#
# conn.close()                 # closing the connection with Mysql DBMS !!

# %% [markdown]
# # note ***

# %% [raw]
# here our database ( pdb ) got created !!

# %% [markdown]
# # Show Database

# %% [raw]
# import mysql.connector
#
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
#
# except:
# 	print('Unable to Connect')
#
#
# sql = 'SHOW DATABASES'   # query !! will give you multiple database names so , we have to iterate using loop !
#
# myc = conn.cursor()
#
# myc.execute(sql)
#
# for db in myc:           # as cursor object ( myc ) points the database names , so we will be iterating  (myc)
# 	print(db)
#
# myc.close()
#
# conn.close()

# %% [raw]
# cursor object ( myc )  : it is an object that is used to make the connection for executing SQL queries
#
# The MySQLCursor of mysql-connector-python (and similar libraries) is used to execute statements to communicate with the MySQL database

# %% [markdown]
# # 81 . How to make connection with database

# %% [raw]
# Connecting to Database :
#
# connect() – This method is used to open or establish a new connection. It returns an object representing the connection.

# %% [markdown]
# # Syntax: -

# %% [raw]
# connection_object = connect(user=‘username’, password=‘pass’, database=‘dbname’,host=‘localhost’, port=3306);
#
#
#
# NOTE :
#
#
# database=‘dbname’   ::   here we have to write the database name with which we wants to connect using our python program !!

# %% [markdown]
# # example: -

# %% [raw]
# import mysql.connector
#
# conn = mysql.connector.connect(user=‘root’, password=‘geek’, host=‘localhost’, database=‘pdb’, port=3306)

# %% [markdown]
# # note**

# %% [raw]
# below image shows us how we are connecting to a DBMS (Mysql) and then to the database (pdb !!) using the python program !!

# %% [markdown]
# ![Screenshot%20%28580%29.png](attachment:Screenshot%20%28580%29.png)

# %% [markdown]
# # Connect Database  , pycharm ::

# %% [raw]
# import mysql.connector
#
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',  # here we have to write the database name with which we wants to connect using our python program !!
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
#
# except:
# 	print('Unable to Connect')
#
#
# conn.close()

# %% [markdown]
# # 82. How to create and show database tables in python

# %% [raw]
# # Create Table
#
#
#
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(           # conn : connection object !!
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
#
# except:
# 	print('Unable to Connect')
#
#
#
# sql = 'CREATE TABLE student1(stuid INT AUTO_INCREMENT PRIMARY KEY, name VARCHAR(20), roll INT, fees FLOAT)'
#
# myc = conn.cursor()         #  conn : connection object !!, and using this connection object we call cursor() method   !!
#                             #  and this cursor() method returns us cursor object ( myc ), which help to execute SQL queries  !!
# myc.execute(sql)
#                             # so after completing the work we must close the cursor object which is a good practice !!
# myc.close()
#
# conn.close()

# %% [markdown]
# # note ***

# %% [raw]
# after writting the query :
#
# sql = 'CREATE TABLE student1(stuid INT AUTO_INCREMENT PRIMARY KEY, name VARCHAR(20), roll INT, fees FLOAT)'
#
#
#
#
# now to execute the query , we now need cursor object ( myc ), and this cursor object will provided to us by cursor () method  , and this cursor object ( myc ) will be used to execute the SQL queries !!
#
#
#
#
#
# myc = conn.cursor()
#
#
# # myc  : cursor object
#
# # conn : connection object !!
#
# # cursor() : method !!

# %% [markdown]
# # now Showing tables !!

# %% [raw]
# # Show Tables
#
#
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
#
# sql = 'SHOW TABLES'
#
# myc = conn.cursor()      # opening the cursor obejct
#
# myc.execute(sql)
#
# for t in myc:    # as there are so many tables in it ,so, we will be iterating through the tables using myc ( cursor object )!!
# 	print(t)
#
# myc.close()              # closing the cursor obejct
#
# conn.close()             # closing the connection with Mysql DBMS !!

# %% [markdown]
# # 83. How to insert data in table in python !!

# %% [markdown]
# # commit() Method :

# %% [raw]
# This method is used to save inserted row in the table. It is required to make the changes, otherwise no changes are made to the table.
#
# This method sends a COMMIT statement to the MySQL server, committing the current transaction. Since by default Connector/Python does  (   not autocommit !!!!   ) , it is important to call this method after every transaction that modifies data for tables that use transactional storage engines.

# %% [markdown]
# # note ***

# %% [raw]
# unless we modify the data inside our table , there is no need of using commit () method .

# %% [markdown]
# # Syntax:-

# %% [raw]
# connection_object.commit()

# %% [raw]
# example :- conn.commit()

# %% [markdown]
# # rollback() Method :

# %% [raw]
# This method is used to un-save row, if there is an error . This method sends a ROLLBACK statement to the MySQL server, undoing all data changes from the current transaction. By default, Connector/Python does not autocommit, so it is possible to cancel transactions when using transactional storage engines such as InnoDB.

# %% [markdown]
# # Syntax:-

# %% [raw]
# connection_object.rollback()

# %% [raw]
# example:- conn.rollback()

# %% [markdown]
# # example :

# %% [raw]
# try:
#     myc.execute(sql)
#     conn.commit()
#
#
# except:
#     conn.rollback()

# %% [markdown]
# # note ***

# %% [raw]
# we cannot use single quote inside the single quotes i.e  (  '  ' '  '  )  this is considered as a wrong practice !!
# so instead of using the single quote use double quotes i.e ( ' " " ' ) !!

# %% [markdown]
# # program :

# %% [raw]
# import mysql.connector
#
# database_name=input("Enter the database name you want to work")
#
# try:
#     conn=mysql.connector.connect(
#         user='root',
#         password="",
#         host='localhost',
#         database= database_name,
#         port=3306
#     )
#     if conn.is_connected():
#         print(database_name,'connected')
# except:
#     print(database_name,"unable to connect !!")
#
#
# sql = "INSERT INTO student(name,roll,fees) VALUES('summit',101,10000.52)"
#
# myc = conn.cursor()
#
# myc.execute(sql)
#
# conn.commit()
#
# myc.close()
#
# conn.close()

# %% [markdown]
# # cmd

# %% [raw]
# MariaDB [pdb]> select * from student;
# +-------+--------+------+---------+
# | stuid | name   | roll | fees    |
# +-------+--------+------+---------+
# |     1 | summit |  101 | 10000.5 |
# +-------+--------+------+---------+
# 1 row in set (0.001 sec)
#
#
# here we can see the data got inserted inside the table !!

# %% [markdown]
# # Insert Multiple Row

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
#
# sql =' INSERT INTO student(name, roll, fees) VALUES("Jai", 104, 40000.50), ("Veeru", 105, 50000.50), ("Basanti", 106,60000.50)'
#
# myc = conn.cursor()
#
# try:
# 	myc.execute(sql)
# 	conn.commit()		                    # Committing the change
# 	print(myc.rowcount, 'Row Inserted')		# Number of Row Inserted
#
#
# except:
# 	conn.rollback()		                    # Rollback the change
# 	print('Unable to Insert Data')
#
# myc.close()		# Close Cursor
# conn.close()	# Close Connection

# %% [markdown]
# # 84. row count property (****imp property )

# %% [markdown]
# # rowcount Property :

# %% [raw]
# This read-only property returns the number of rows returned for SELECT statements, or the number of rows affected by DML statements such as INSERT or UPDATE.
#
# i.e it will be simply counting how many no. of rows are being inserted and updated !!

# %% [markdown]
# # Syntax:-

# %% [raw]
# cursor_object.rowcount

# %% [raw]
# example:- myc.rowcount

# %% [markdown]
# # exmaple :  # Insert Single Row

# %% [raw]
# import mysql.connector
#
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
#
# sql = 'INSERT INTO student(name, roll, fees) VALUES("Sumit", 103, 30000.50)'
# myc = conn.cursor()
#
#
# try:
# 	myc.execute(sql)
# 	conn.commit()		                        # Committing the change
# 	print(myc.rowcount, 'Row Inserted')		    # Number of Row Inserted
#
#
# except:
# 	conn.rollback()		                        # Rollback the change
# 	print('Unable to Insert Data')
#
# myc.close()		# Close Cursor
# conn.close()	# Close Connection

# %% [markdown]
# # 85. lastrowid property  (***imp !!)

# %% [raw]
# This read-only property returns the value generated for an [ AUTO_INCREMENT column ] by the previous INSERT or UPDATE statement or None when there is no such value available.

# %% [markdown]
# # note *** :

# %% [raw]
# * If you perform an INSERT into a table that contains an AUTO_INCREMENT column, lastrowid returns the AUTO_INCREMENT value for   the ( new row ) .
#
#
# * If you insert multiple rows into a table using a single INSERT statement, the lastrowidproperty contains the last insert id     of the ( first row ).

# %% [markdown]
# # Syntax:-

# %% [raw]
# cursor_object.lastrowid

# %% [raw]
# example :- myc.lastrowid

# %% [markdown]
# # example : # Insert Single Row

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
# sql = 'INSERT INTO student(name, roll, fees) VALUES("Sumit", 103, 30000.50)'
#
# myc = conn.cursor()
#
#
# try:
# 	myc.execute(sql)
# 	conn.commit()		                         # Committing the change
# 	print(myc.rowcount, 'Row Inserted')		     # Number of Row Inserted
# 	print(myc.lastrowid)	                     # Last inserted ID
#
#
# except:
# 	conn.rollback()		                         # Rollback the change
# 	print('Unable to Insert Data')
#
# myc.close()		# Close Cursor
#
# conn.close()	# Close Connection

# %% [markdown]
# # Insert Multiple Row

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
#
# sql = 'INSERT INTO student(name, roll, fees) VALUES("Jai", 104, 40000.50), ("Veeru", 105, 50000.50), ("Basanti", 106,60000.50)'
#
# myc = conn.cursor()
#
# try:
# 	myc.execute(sql)
# 	conn.commit()		                    # Committing the change
# 	print(myc.rowcount, 'Row Inserted')		# Number of Row Inserted
#
#
# except:
# 	conn.rollback()		                    # Rollback the change
# 	print('Unable to delete Data')
#
#
# myc.close()		# Close Cursor
# conn.close()	# Close Connection

# %% [markdown]
# # 86. how to delete the data from table in python

# %% [markdown]
# # Delete Row

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
# sql = 'DELETE FROM student WHERE stuid=1'
#
# myc = conn.cursor()
#
# try:
# 	myc.execute(sql)
# 	conn.commit()		                   # Committing the change
# 	print(myc.rowcount, 'Row Deleted')     # myc.rowcount:  gives us the number of rows affected by DML statements such as
#                                            # INSERT or UPDATE.
# except:
# 	conn.rollback()		                   # Rollback the change
# 	print('Unable to Delete Data')
#
# myc.close()		                           # Close Cursor
#
# conn.close()	                           # Close Connection

# %% [markdown]
# # 87. How to update data in table in python !!

# %% [markdown]
# # Update Row :

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
#
# sql = 'UPDATE student SET fees=200 WHERE stuid=4'
#
# myc = conn.cursor()
#
# try:
# 	myc.execute(sql)
# 	conn.commit()		                 # Committing the change
# 	print(myc.rowcount, 'Row Updated')
#
# except:
# 	conn.rollback()		                 # Rollback the change
# 	print('Unable to Update Data')
#
# myc.close()		                         # Close Cursor
#
# conn.close()	                         # Close Connection

# %% [markdown]
# # 88. How to fetch data from table using fetchone method in python !

# %% [markdown]
# # fetchone() Method

# %% [raw]
# This method retrieves the next row of a query result set and returns a single sequence, or None if no more rows are available. By default, the returned tuple consists of data returned by the MySQL server, converted to Python objects. If the cursor is a raw cursor, no such conversion occurs.
#
# You must fetch all rows for the current query before executing new statements using the same connection.

# %% [markdown]
# # Syntax:-

# %% [raw]
# row = cursor_object.fetchone()

# %% [raw]
# example :- row = myc.fetchone()

# %% [markdown]
# # example :  Retrieve Row one by one

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
#
#
# sql = 'SELECT * FROM student'
# myc = conn.cursor()
#
#
# try:
# 	myc.execute(sql)
# 	row = myc.fetchone()
# 	while row is not None:
# 		print(row)
# 		row = myc.fetchone()
#
# 	print('Total Rows:',myc.rowcount)
#
# except:
# 	print('Unable to Retrieve Data')
#
# myc.close()		# Close Cursor
#
# conn.close()	# Close Connection

# %% [markdown]
# # example :  Retrieve Row one by one (using indexing !!)

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
# sql = 'SELECT * FROM student'
#
# myc = conn.cursor()
#
# try:
# 	myc.execute(sql)
# 	row = myc.fetchone()
# 	while row is not None:
# 		stuid = row[0]                                                     # as we can use indexing in the tuple !!
# 		name =  row[1]
# 		roll =  row[2]
# 		fees =  row[3]
# 		print(f'StuID: {stuid} Name: {name} Roll: {roll} Fees: {fees}')
# 		row = myc.fetchone()                                               # it will fetch the next row data !!
#
# 	print('Total Rows:',myc.rowcount)
#
# except:
# 	print('Unable to Retrieve Data')
#
# myc.close()		             # Close Cursor
# conn.close()	             # Close Connection

# %% [markdown]
# # 89. How to fetch Data from table using fetchall method

# %% [markdown]
# # Note:

# %% [raw]
#  We use the fetchall() method, which fetches all rows from the last executed statement.

# %% [markdown]
# # fetchall() Method :

# %% [raw]
# This method fetches all (or all remaining) rows of a query result set and returns a list of tuples. If no more rows are available, it returns an empty list.
#
# You must fetch all rows for the current query before executing new statements using the same connection.
#
#
# NOTE : if we had already fetched some data from our database then after that  if we are using the fetchall() method the it will        only fetch the remaining data !! , not the whole data !!

# %% [markdown]
# # Syntax:-

# %% [raw]
# rows = cursor_object.fetchall()

# %% [markdown]
# # example :

# %% [raw]
# rows = myc.fetchall()

# %% [markdown]
# # Retrieve All Rows program

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
#
# sql = 'SELECT * FROM student'
# myc = conn.cursor()
#
# try:
# 	myc.execute(sql)
# 	rows = myc.fetchall()
# 	for r in rows:
# 		print(r)
# 	print('Total Rows:',myc.rowcount)
#
# except:
# 	print('Unable to Retrieve Data')
#
# myc.close()		                       # Close Cursor
#
# conn.close()	                       # Close Connection

# %% [markdown]
# # Retrieve All Rows with formatted output

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
# sql = 'SELECT * FROM student'
#
# myc = conn.cursor()
#
# try:
# 	myc.execute(sql)
# 	rows = myc.fetchall()
# 	for r in rows:
# 		stuid = r[0]
# 		name = r[1]
# 		roll = r[2]
# 		fees = r[3]
# 		print(f'StuID: {stuid} Name: {name} Roll: {roll} Fees: {fees}')
# 	print('Total Rows:',myc.rowcount)
#
# except:
# 	print('Unable to Retrieve Data')
#
# myc.close()		         # Close Cursor
#
# conn.close()	         # Close Connection

# %% [markdown]
# # 90.fetchmany() Method

# %% [raw]
# This method fetches the next set of rows of a query result and returns a list of tuples. If no more rows are available, it returns an empty list.
#
# The number of rows returned can be specified using the size argument, which defaults to one. Fewer rows are returned if fewer rows are available than specified.
#
# You must fetch all rows for the current query before executing new statements using the same connection.

# %% [markdown]
# # Syntax:-

# %% [raw]
# rows = cursor_object.fetchmany(size=1)

# %% [markdown]
# # example :

# %% [raw]
# rows = myc.fetchmany(3)
#
# so , if have given the ( size =3 ) then it will give us the set of 3 tuple in format of list .

# %% [markdown]
# # note***

# %% [raw]
# eariler we were using [ myc = conn.cursor()  ] which ,we were closing after completing the whole operation !!
#
# but here we will be fetching only few rows using [  fetchmany(5)  ] so we can't close the cursor using [ myc.close() ] unless we have performed the whole operation, which is fetching complete rows data !!

# %% [raw]
# so, it will produce an error to us !! , so instead of using [  myc = conn.cursor()  ]  we will be using :
#
# * myc = conn.cursor(buffered=True)

# %% [markdown]
# # * eg:- myc = conn.cursor(buffered=True)

# %% [raw]
# so , here in case of fetchmany() we will use ( buffered=True  ), which basically behind the scene  will fetch all the rows !!
#
# eg:- myc = conn.cursor(buffered=True)

# %% [markdown]
# # Retrieve Number of Rows using [ myc = conn.cursor(buffered=True)¶]

# %% [raw]
# # Retrieve Number of Rows
#
# import mysql.connector
#
# conn= mysql.connector.connect(
# 	user='root',
# 	password='geek',
# 	host='localhost',
# 	database='pdb',
# 	port=3306
# )
# if (conn.is_connected()):
# 	print('Connected')
#
# sql = 'SELECT * FROM student'
#
# myc = conn.cursor(buffered=True)
#
# myc.execute(sql)
#
# rows = myc.fetchmany(size=5)
# for row in rows:
# 	print(row)
#
# print('Total Rows:',myc.rowcount)    # but as we have used (buffered=True) it will fetch all the rows i.e 55 , but o/p will be
#                                      # of only 5 rows as [ fetchmany(size=5) ] size has been given by us !!
#
# myc.close()		                     # Close Cursor
#
# conn.close()	                     # Close Connection

# %% [markdown]
# # ROWCOUNT :

# %% [raw]
# ROWCOUNT yields the number of rows affected by an INSERT , UPDATE , or DELETE statement, or returned by a SELECT INTO
# statement. ROWCOUNT yields 0 if an INSERT , UPDATE , or DELETE statement affected no rows, or a SELECT INTO statement returned no rows.

# %% [markdown]
# # 91. Retrieve Single Row with WHERE Clause

# %% [raw]
# # import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
#
# sql = 'SELECT * FROM student WHERE stuid=4'
#
# myc = conn.cursor()
#
# try:
# 	myc.execute(sql)               # executing the sql query !!
# 	row = myc.fetchone()           # it will fetch the data with " stuid=4 "
# 	print(row)                     # it will show the data of row fetched , i.e ( stuid=4  ) data !!
# 	print('Total Rows:',myc.rowcount)
#
# except:
# 	print('Unable to Retrieve Data')
#
# myc.close()		                   # Close Cursor
#
# conn.close()	                   # Close Connection

# %% [markdown]
# # note ****** most imp !!!

# %% [raw]
# * fetchone() Method : This method retrieves the next row of a query result set and returns a single sequence, or None if no       more rows are available.
#
#
# * ROWCOUNT : is a system variable that is used to return the number of rows that are affected by the last executed statement in   the batch.

# %% [markdown]
# # Retrieve Single Row with WHERE Clause

# %% [raw]
# import mysql.connector
#
# try:
# 	conn= mysql.connector.connect(
# 		user='root',
# 		password='geek',
# 		host='localhost',
# 		database='pdb',
# 		port=3306
# 	)
# 	if (conn.is_connected()):
# 		print('Connected')
#
# except:
# 	print('Unable to Connect')
#
# sql = 'SELECT * FROM student WHERE roll=777'
# myc = conn.cursor()
#
# try:
# 	myc.execute(sql)
# 	row = myc.fetchone()
# 	while row is not None:
# 		print(row)
# 		row = myc.fetchone()             # it will fetch the next row !!
# 	print('Total Rows:',myc.rowcount)
#
# except:
# 	print('Unable to Retrieve Data')
#
# myc.close()		                         # Close Cursor
#
# conn.close()	                         # Close Connection

# %% [markdown]
# # 92. parameterized query in python

# %% [raw]
# Parameterized Query :
#
# A parameterized query is a query which can use the format or pyformatparameterization style for parameters and the parameter values supplied at execution.
#
# These executed with MySQLCursor can use the %s and %(key)s format style.
#
# * %s        ---> is used as format style in the sql queries, while using tuple parameters.
# * %(key)s   ---> is used as format style in the sql queries, while using dictionary parameters.
#
# myc = conn.cursor()

# %% [markdown]
# # Tuple Parameters

# %% [raw]
# sql = 'INSERT INTO student(name, roll, fees) VALUES(%s, %s, %s)'
#
# #note: the 1st ' %s ' is mapped with the' name ',which means they are in particular order as defined here : (name, roll, fees )
#
#
#
#
# myc = conn.cursor()
#
# params = ("Rohan", 111, 60000.50)   # tuple format !!
#
# myc.execute(sql, params)

# %% [markdown]
# # Dictionary Parameters

# %% [raw]
# sql = 'INSERT INTO student(name, roll, fees) VALUES( %(name)s ,  %(roll)s ,  %(fees)s )‘
#
# myc = conn.cursor()
#
# params = { 'name': 'Kajal', 'roll': 777, 'fees': 54100 }   # dictionary format !!
#
# myc.execute(sql, params)

# %% [markdown]
# # note :

# %% [raw]
# we usually write ( %s ) when we want the values in tuple format !!

# %% [markdown]
# # note :

# %% [raw]
# sql =‘SELECT * FROM student’
# myc = conn.cursor()
# myc.execute(sql,params)

# %% [markdown]
# # Syntax:-

# %% [raw]
# cursor_object.execute(sql, param=None, multi=False)

# %% [raw]
# * Sql – It is sql query.
#
#
# * Param – The parameters found in the tuple or dictionary params are bound to the variables in the operation.
#
#
# * Multi – execute() returns an iterator if multi is True.
#
#
#
# Param – The parameters found in the tuple or dictionary params are bound to the variables in the operation / sql query .
#
# so , everything we write in our sql query this tupel or dictionary will be bound to it !! . So which ever we use it will be bound to our sql query !!

# %% [markdown]
# # 95. input from user into table parameterized query tuple in python

# %% [markdown]
# # self made program !! :

# %% [raw]
# import mysql.connector
#
# try:
#     conn=mysql.connector.connect(
#         user='root',
#         host="localhost",
#         password='',
#         port=3306,
#         database='pdb'
#     )
#     if conn.is_connected():
#         print("connected")
#
# except:
#     print("unable to connect !!")
#
#
# def myfunc(a,b,c,d):
#     try:
#         val = [
#             [a, b, c, d]
#         ]
#         print()
#         myc = conn.cursor()
#         myc.executemany(sql, val)
#         conn.commit()
#
#
#
#     except:
#         print("unable to insert !!")
#
#
# a=int(input(' enter the no. of rows you want to fill : '))
# i=1
# while a >= i:
#     print('enter for row :', i)
#     print()
#     sql = "INSERT INTO student VALUES(%s ,%s ,%s ,%s)"
#     w = input("enter the stuid ")
#     x = input("enter the name")
#     y = input("enter the roll no")
#     z = input("enter the fees :")
#     i=i+1
#     ans=input('do you want to exit ?? ')
#     if ans=='y':
#         break
#     else:
#         myfunc(w,x,y,z)
#
#
#
#
# print("completed !!")

# %% [markdown]
# # 98. input from user using dictionary format !!

# %% [raw]
# import mysql.connector
#
# try:
#
#     conn=mysql.connector.connect(
#         user='root',
#         host="localhost",
#         password='',
#         port=3306,
#         database='pdb'
#     )
#     if conn.is_connected():
#         print("connected")
#
# except:
#
#     print("unable to connect !!")
#
#
# def myfunc(a,b,c,d):
#
#     try:
#
#         val ={ 'stuid': a, 'name': b, 'roll':c, 'fees': d }  # dictionary format !!
#         print()
#         myc = conn.cursor()
#         myc.execute(sql, val)
#         conn.commit()
#
#
#
#     except:
#
#         print("unable to insert !!")
#
#
# a=int(input(' enter the no. of rows you want to fill : '))
#
# i=1
#
# while a >= i:
#
#     print('enter for row :', i)
#
#     print()
#
#     sql = "INSERT INTO student VALUES( %(stuid)s ,%(name)s ,  %(roll)s ,  %(fees)s )"
#     w = input("enter the stuid ")
#     x = input("enter the name")
#     y = input("enter the roll no")
#     z = input("enter the fees :")
#     ans = input('do you want to exit ?? ')
#
#     i = i + 1
#
#     myfunc(w, x, y, z)
#
#     if ans == 'y':
#         break
#
# print("completed !!")

# %% [markdown]
# # 99. How to delete data from table parameterized query in python  using tuple format !!

# %% [raw]
# import mysql.connector
#
# try:
#
#     conn=mysql.connector.connect(
#         user='root',
#         host="localhost",
#         password='',
#         port=3306,
#         database='mydb'
#     )
#     if conn.is_connected():
#         print("connected")
#
# except:
#
#     print("unable to connect !!")
#
#
#
# sql ='DELETE from orders where ordr_id=%s'
#
# myc = conn.cursor()
#
# row_no=input("enter the row you want to delete : ")
#
# del_value=(row_no,)        # tuple format so using (,) for entering single value !!   # this row_no will be passed to %s !!
#
#
#
# try:
#
#     myc.execute(sql,del_value)
#     conn.commit()
#     print('DELETED SUCCESSFULY !!')
#     myc.close()
#     conn.close()
#
#
#
# except:
#
#     print("unable to delete !!")

# %% [markdown]
# # 100. UPDATE data in table parameterized query in python !!

# %% [raw]
# import mysql.connector
#
# try:
#
#     conn=mysql.connector.connect(
#         user='root',
#         host="localhost",
#         password='',
#         port=3306,
#         database='mydb'
#     )
#     if conn.is_connected():
#         print("connected")
#
# except:
#
#     print("unable to connect !!")
#
# sql = "UPDATE orders SET new_name=%s where ordr_id=%s"
#
# myc = conn.cursor()
#
# name=input('enter the name you want :')
#
# row_no=input("enter the row you want to update: ")
#
# up_value=(name,row_no)   # this name will be passed to 1st ( new_name ) ' %s ' and (row_no) will be passed to ( ordr_id) ' %S '
#
# try:
#     myc.execute(sql,up_value)       # this name will be passed to 1st %s and row_no will be passed to 2nd %S !!
#     conn.commit()
#     print('UPDATED SUCCESSFULY !!')
#     myc.close()
#     conn.close()
#
#
#
# except:
#     print("unable to update !!")

# %% [markdown]
# # note *** most imp point  !!

# %% [raw]
# up_value=(name,row_no)   # this name will be passed to 1st ( new_name ) ' %s ' and (row_no) will be passed to ( ordr_id) ' %S '
